# %%
import csv
import pandas as pd
import numpy as np
from functools import partial, reduce

import random

import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Data Importation

# %%
######################## Importing the data as a pandas dataframe: ########################

WDbk_af = pd.read_csv('/content/drive/My Drive/CS6140_Project/dynamic_walk_1_butt-kicks/AB01_dynamic_walk_1_butt-kicks_activity_flag.csv');
WDbk_angle = pd.read_csv('/content/drive/My Drive/CS6140_Project/dynamic_walk_1_butt-kicks/AB01_dynamic_walk_1_butt-kicks_angle.csv');
WDbk_emg = pd.read_csv('/content/drive/My Drive/CS6140_Project/dynamic_walk_1_butt-kicks/AB01_dynamic_walk_1_butt-kicks_emg.csv');
WDbk_grf = pd.read_csv('/content/drive/My Drive/CS6140_Project/dynamic_walk_1_butt-kicks/AB01_dynamic_walk_1_butt-kicks_grf.csv');
WDbk_imu_real = pd.read_csv('/content/drive/My Drive/CS6140_Project/dynamic_walk_1_butt-kicks/AB01_dynamic_walk_1_butt-kicks_imu_real.csv');
WDbk_imu_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/dynamic_walk_1_butt-kicks/AB01_dynamic_walk_1_butt-kicks_imu_sim.csv');
WDbk_insole_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/dynamic_walk_1_butt-kicks/AB01_dynamic_walk_1_butt-kicks_insole_sim.csv');
WDbk_moment = pd.read_csv('/content/drive/My Drive/CS6140_Project/dynamic_walk_1_butt-kicks/AB01_dynamic_walk_1_butt-kicks_moment.csv');
WDbk_power = pd.read_csv('/content/drive/My Drive/CS6140_Project/dynamic_walk_1_butt-kicks/AB01_dynamic_walk_1_butt-kicks_power.csv');
WDbk_velocity = pd.read_csv('/content/drive/My Drive/CS6140_Project/dynamic_walk_1_butt-kicks/AB01_dynamic_walk_1_butt-kicks_velocity.csv');

WDhw_angle = pd.read_csv('/content/drive/My Drive/CS6140_Project/dynamic_walk_1_heel-walk/AB01_dynamic_walk_1_heel-walk_angle.csv');
WDhw_emg = pd.read_csv('/content/drive/My Drive/CS6140_Project/dynamic_walk_1_heel-walk/AB01_dynamic_walk_1_heel-walk_emg.csv');
WDhw_grf = pd.read_csv('/content/drive/My Drive/CS6140_Project/dynamic_walk_1_heel-walk/AB01_dynamic_walk_1_heel-walk_grf.csv');
WDhw_imu_real = pd.read_csv('/content/drive/My Drive/CS6140_Project/dynamic_walk_1_heel-walk/AB01_dynamic_walk_1_heel-walk_imu_real.csv');
WDhw_imu_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/dynamic_walk_1_heel-walk/AB01_dynamic_walk_1_heel-walk_imu_sim.csv');
WDhw_insole_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/dynamic_walk_1_heel-walk/AB01_dynamic_walk_1_heel-walk_insole_sim.csv');
WDhw_moment = pd.read_csv('/content/drive/My Drive/CS6140_Project/dynamic_walk_1_heel-walk/AB01_dynamic_walk_1_heel-walk_moment.csv');
WDhw_power = pd.read_csv('/content/drive/My Drive/CS6140_Project/dynamic_walk_1_heel-walk/AB01_dynamic_walk_1_heel-walk_power.csv');
WDhw_velocity = pd.read_csv('/content/drive/My Drive/CS6140_Project/dynamic_walk_1_heel-walk/AB01_dynamic_walk_1_heel-walk_velocity.csv');

WDhk_af = pd.read_csv('/content/drive/My Drive/CS6140_Project/dynamic_walk_1_high-knees/AB01_dynamic_walk_1_high-knees_activity_flag.csv');
WDhk_angle = pd.read_csv('/content/drive/My Drive/CS6140_Project/dynamic_walk_1_high-knees/AB01_dynamic_walk_1_high-knees_angle.csv');
WDhk_emg = pd.read_csv('/content/drive/My Drive/CS6140_Project/dynamic_walk_1_high-knees/AB01_dynamic_walk_1_high-knees_emg.csv');
WDhk_grf = pd.read_csv('/content/drive/My Drive/CS6140_Project/dynamic_walk_1_high-knees/AB01_dynamic_walk_1_high-knees_grf.csv');
WDhk_imu_real = pd.read_csv('/content/drive/My Drive/CS6140_Project/dynamic_walk_1_high-knees/AB01_dynamic_walk_1_high-knees_imu_real.csv');
WDhk_imu_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/dynamic_walk_1_high-knees/AB01_dynamic_walk_1_high-knees_imu_sim.csv');
WDhk_insole_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/dynamic_walk_1_high-knees/AB01_dynamic_walk_1_high-knees_insole_sim.csv');
WDhk_moment = pd.read_csv('/content/drive/My Drive/CS6140_Project/dynamic_walk_1_high-knees/AB01_dynamic_walk_1_high-knees_moment.csv');
WDhk_power = pd.read_csv('/content/drive/My Drive/CS6140_Project/dynamic_walk_1_high-knees/AB01_dynamic_walk_1_high-knees_power.csv');
WDhk_velocity = pd.read_csv('/content/drive/My Drive/CS6140_Project/dynamic_walk_1_high-knees/AB01_dynamic_walk_1_high-knees_velocity.csv');

WDtw_af = pd.read_csv('/content/drive/My Drive/CS6140_Project/dynamic_walk_1_toe-walk/AB01_dynamic_walk_1_toe-walk_activity_flag.csv');
WDtw_angle = pd.read_csv('/content/drive/My Drive/CS6140_Project/dynamic_walk_1_toe-walk/AB01_dynamic_walk_1_toe-walk_angle.csv');
WDtw_emg = pd.read_csv('/content/drive/My Drive/CS6140_Project/dynamic_walk_1_toe-walk/AB01_dynamic_walk_1_toe-walk_emg.csv');
WDtw_grf = pd.read_csv('/content/drive/My Drive/CS6140_Project/dynamic_walk_1_toe-walk/AB01_dynamic_walk_1_toe-walk_grf.csv');
WDtw_imu_real = pd.read_csv('/content/drive/My Drive/CS6140_Project/dynamic_walk_1_toe-walk/AB01_dynamic_walk_1_toe-walk_imu_real.csv');
WDtw_imu_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/dynamic_walk_1_toe-walk/AB01_dynamic_walk_1_toe-walk_imu_sim.csv');
WDtw_insole_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/dynamic_walk_1_toe-walk/AB01_dynamic_walk_1_toe-walk_insole_sim.csv');
WDtw_moment = pd.read_csv('/content/drive/My Drive/CS6140_Project/dynamic_walk_1_toe-walk/AB01_dynamic_walk_1_toe-walk_moment.csv');
WDtw_power = pd.read_csv('/content/drive/My Drive/CS6140_Project/dynamic_walk_1_toe-walk/AB01_dynamic_walk_1_toe-walk_power.csv');
WDtw_velocity = pd.read_csv('/content/drive/My Drive/CS6140_Project/dynamic_walk_1_toe-walk/AB01_dynamic_walk_1_toe-walk_velocity.csv');

WId5_af = pd.read_csv('/content/drive/My Drive/CS6140_Project/incline_walk_1_down5/AB01_incline_walk_1_down5_activity_flag.csv');
WId5_angle = pd.read_csv('/content/drive/My Drive/CS6140_Project/incline_walk_1_down5/AB01_incline_walk_1_down5_angle.csv');
WId5_emg = pd.read_csv('/content/drive/My Drive/CS6140_Project/incline_walk_1_down5/AB01_incline_walk_1_down5_emg.csv');
WId5_grf = pd.read_csv('/content/drive/My Drive/CS6140_Project/incline_walk_1_down5/AB01_incline_walk_1_down5_grf.csv');
WId5_imu_real = pd.read_csv('/content/drive/My Drive/CS6140_Project/incline_walk_1_down5/AB01_incline_walk_1_down5_imu_real.csv');
WId5_imu_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/incline_walk_1_down5/AB01_incline_walk_1_down5_imu_sim.csv');
WId5_insole_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/incline_walk_1_down5/AB01_incline_walk_1_down5_insole_sim.csv');
WId5_moment = pd.read_csv('/content/drive/My Drive/CS6140_Project/incline_walk_1_down5/AB01_incline_walk_1_down5_moment.csv');
WId5_power = pd.read_csv('/content/drive/My Drive/CS6140_Project/incline_walk_1_down5/AB01_incline_walk_1_down5_power.csv');
WId5_velocity = pd.read_csv('/content/drive/My Drive/CS6140_Project/incline_walk_1_down5/AB01_incline_walk_1_down5_velocity.csv');

WIu5_af = pd.read_csv('/content/drive/My Drive/CS6140_Project/incline_walk_1_up5/AB01_incline_walk_1_up5_activity_flag.csv');
WIu5_angle = pd.read_csv('/content/drive/My Drive/CS6140_Project/incline_walk_1_up5/AB01_incline_walk_1_up5_angle.csv');
WIu5_emg = pd.read_csv('/content/drive/My Drive/CS6140_Project/incline_walk_1_up5/AB01_incline_walk_1_up5_emg.csv');
WIu5_grf = pd.read_csv('/content/drive/My Drive/CS6140_Project/incline_walk_1_up5/AB01_incline_walk_1_up5_grf.csv');
WIu5_imu_real = pd.read_csv('/content/drive/My Drive/CS6140_Project/incline_walk_1_up5/AB01_incline_walk_1_up5_imu_real.csv');
WIu5_imu_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/incline_walk_1_up5/AB01_incline_walk_1_up5_imu_sim.csv');
WIu5_insole_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/incline_walk_1_up5/AB01_incline_walk_1_up5_insole_sim.csv');
WIu5_moment = pd.read_csv('/content/drive/My Drive/CS6140_Project/incline_walk_1_up5/AB01_incline_walk_1_up5_moment.csv');
WIu5_power = pd.read_csv('/content/drive/My Drive/CS6140_Project/incline_walk_1_up5/AB01_incline_walk_1_up5_power.csv');
WIu5_velocity = pd.read_csv('/content/drive/My Drive/CS6140_Project/incline_walk_1_up5/AB01_incline_walk_1_up5_velocity.csv');

WId10_af = pd.read_csv('/content/drive/My Drive/CS6140_Project/incline_walk_2_down10/AB01_incline_walk_2_down10_activity_flag.csv');
WId10_angle = pd.read_csv('/content/drive/My Drive/CS6140_Project/incline_walk_2_down10/AB01_incline_walk_2_down10_angle.csv');
WId10_emg = pd.read_csv('/content/drive/My Drive/CS6140_Project/incline_walk_2_down10/AB01_incline_walk_2_down10_emg.csv');
WId10_grf = pd.read_csv('/content/drive/My Drive/CS6140_Project/incline_walk_2_down10/AB01_incline_walk_2_down10_grf.csv');
WId10_imu_real = pd.read_csv('/content/drive/My Drive/CS6140_Project/incline_walk_2_down10/AB01_incline_walk_2_down10_imu_real.csv');
WId10_imu_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/incline_walk_2_down10/AB01_incline_walk_2_down10_imu_sim.csv');
WId10_insole_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/incline_walk_2_down10/AB01_incline_walk_2_down10_insole_sim.csv');
WId10_moment = pd.read_csv('/content/drive/My Drive/CS6140_Project/incline_walk_2_down10/AB01_incline_walk_2_down10_moment.csv');
WId10_power = pd.read_csv('/content/drive/My Drive/CS6140_Project/incline_walk_2_down10/AB01_incline_walk_2_down10_power.csv');
WId10_velocity = pd.read_csv('/content/drive/My Drive/CS6140_Project/incline_walk_2_down10/AB01_incline_walk_2_down10_velocity.csv');

WIu10_af = pd.read_csv('/content/drive/My Drive/CS6140_Project/incline_walk_2_up10/AB01_incline_walk_2_up10_activity_flag.csv');
WIu10_angle = pd.read_csv('/content/drive/My Drive/CS6140_Project/incline_walk_2_up10/AB01_incline_walk_2_up10_angle.csv');
WIu10_emg = pd.read_csv('/content/drive/My Drive/CS6140_Project/incline_walk_2_up10/AB01_incline_walk_2_up10_emg.csv');
WIu10_grf = pd.read_csv('/content/drive/My Drive/CS6140_Project/incline_walk_2_up10/AB01_incline_walk_2_up10_grf.csv');
WIu10_imu_real = pd.read_csv('/content/drive/My Drive/CS6140_Project/incline_walk_2_up10/AB01_incline_walk_2_up10_imu_real.csv');
WIu10_imu_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/incline_walk_2_up10/AB01_incline_walk_2_up10_imu_sim.csv');
WIu10_insole_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/incline_walk_2_up10/AB01_incline_walk_2_up10_insole_sim.csv');
WIu10_moment = pd.read_csv('/content/drive/My Drive/CS6140_Project/incline_walk_2_up10/AB01_incline_walk_2_up10_moment.csv');
WIu10_power = pd.read_csv('/content/drive/My Drive/CS6140_Project/incline_walk_2_up10/AB01_incline_walk_2_up10_power.csv');
WIu10_velocity = pd.read_csv('/content/drive/My Drive/CS6140_Project/incline_walk_2_up10/AB01_incline_walk_2_up10_velocity.csv');

WN06_af = pd.read_csv('/content/drive/My Drive/CS6140_Project/normal_walk_1_0-6/AB01_normal_walk_1_0-6_activity_flag.csv');
WN06_angle = pd.read_csv('/content/drive/My Drive/CS6140_Project/normal_walk_1_0-6/AB01_normal_walk_1_0-6_angle.csv');
WN06_emg = pd.read_csv('/content/drive/My Drive/CS6140_Project/normal_walk_1_0-6/AB01_normal_walk_1_0-6_emg.csv');
WN06_grf = pd.read_csv('/content/drive/My Drive/CS6140_Project/normal_walk_1_0-6/AB01_normal_walk_1_0-6_grf.csv');
WN06_imu_real = pd.read_csv('/content/drive/My Drive/CS6140_Project/normal_walk_1_0-6/AB01_normal_walk_1_0-6_imu_real.csv');
WN06_imu_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/normal_walk_1_0-6/AB01_normal_walk_1_0-6_imu_sim.csv');
WN06_insole_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/normal_walk_1_0-6/AB01_normal_walk_1_0-6_insole_sim.csv');
WN06_moment = pd.read_csv('/content/drive/My Drive/CS6140_Project/normal_walk_1_0-6/AB01_normal_walk_1_0-6_moment.csv');
WN06_power = pd.read_csv('/content/drive/My Drive/CS6140_Project/normal_walk_1_0-6/AB01_normal_walk_1_0-6_power.csv');
WN06_velocity = pd.read_csv('/content/drive/My Drive/CS6140_Project/normal_walk_1_0-6/AB01_normal_walk_1_0-6_velocity.csv');

WN12_af = pd.read_csv('/content/drive/My Drive/CS6140_Project/normal_walk_1_1-2/AB01_normal_walk_1_1-2_activity_flag.csv');
WN12_angle = pd.read_csv('/content/drive/My Drive/CS6140_Project/normal_walk_1_1-2/AB01_normal_walk_1_1-2_angle.csv');
WN12_emg = pd.read_csv('/content/drive/My Drive/CS6140_Project/normal_walk_1_1-2/AB01_normal_walk_1_1-2_emg.csv');
WN12_grf = pd.read_csv('/content/drive/My Drive/CS6140_Project/normal_walk_1_1-2/AB01_normal_walk_1_1-2_grf.csv');
WN12_imu_real = pd.read_csv('/content/drive/My Drive/CS6140_Project/normal_walk_1_1-2/AB01_normal_walk_1_1-2_imu_real.csv');
WN12_imu_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/normal_walk_1_1-2/AB01_normal_walk_1_1-2_imu_sim.csv');
WN12_insole_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/normal_walk_1_1-2/AB01_normal_walk_1_1-2_insole_sim.csv');
WN12_moment = pd.read_csv('/content/drive/My Drive/CS6140_Project/normal_walk_1_1-2/AB01_normal_walk_1_1-2_moment.csv');
WN12_power = pd.read_csv('/content/drive/My Drive/CS6140_Project/normal_walk_1_1-2/AB01_normal_walk_1_1-2_power.csv');
WN12_velocity = pd.read_csv('/content/drive/My Drive/CS6140_Project/normal_walk_1_1-2/AB01_normal_walk_1_1-2_velocity.csv');

WN18_af = pd.read_csv('/content/drive/My Drive/CS6140_Project/normal_walk_1_1-8/AB01_normal_walk_1_1-8_activity_flag.csv');
WN18_angle = pd.read_csv('/content/drive/My Drive/CS6140_Project/normal_walk_1_1-8/AB01_normal_walk_1_1-8_angle.csv');
WN18_emg = pd.read_csv('/content/drive/My Drive/CS6140_Project/normal_walk_1_1-8/AB01_normal_walk_1_1-8_emg.csv');
WN18_grf = pd.read_csv('/content/drive/My Drive/CS6140_Project/normal_walk_1_1-8/AB01_normal_walk_1_1-8_grf.csv');
WN18_imu_real = pd.read_csv('/content/drive/My Drive/CS6140_Project/normal_walk_1_1-8/AB01_normal_walk_1_1-8_imu_real.csv');
WN18_imu_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/normal_walk_1_1-8/AB01_normal_walk_1_1-8_imu_sim.csv');
WN18_insole_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/normal_walk_1_1-8/AB01_normal_walk_1_1-8_insole_sim.csv');
WN18_moment = pd.read_csv('/content/drive/My Drive/CS6140_Project/normal_walk_1_1-8/AB01_normal_walk_1_1-8_moment.csv');
WN18_power = pd.read_csv('/content/drive/My Drive/CS6140_Project/normal_walk_1_1-8/AB01_normal_walk_1_1-8_power.csv');
WN18_velocity = pd.read_csv('/content/drive/My Drive/CS6140_Project/normal_walk_1_1-8/AB01_normal_walk_1_1-8_velocity.csv');

WN20_af = pd.read_csv('/content/drive/My Drive/CS6140_Project/normal_walk_1_2-0/AB01_normal_walk_1_2-0_activity_flag.csv');
WN20_angle = pd.read_csv('/content/drive/My Drive/CS6140_Project/normal_walk_1_2-0/AB01_normal_walk_1_2-0_angle.csv');
WN20_emg = pd.read_csv('/content/drive/My Drive/CS6140_Project/normal_walk_1_2-0/AB01_normal_walk_1_2-0_emg.csv');
WN20_grf = pd.read_csv('/content/drive/My Drive/CS6140_Project/normal_walk_1_2-0/AB01_normal_walk_1_2-0_grf.csv');
WN20_imu_real = pd.read_csv('/content/drive/My Drive/CS6140_Project/normal_walk_1_2-0/AB01_normal_walk_1_2-0_imu_real.csv');
WN20_imu_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/normal_walk_1_2-0/AB01_normal_walk_1_2-0_imu_sim.csv');
WN20_insole_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/normal_walk_1_2-0/AB01_normal_walk_1_2-0_insole_sim.csv');
WN20_moment = pd.read_csv('/content/drive/My Drive/CS6140_Project/normal_walk_1_2-0/AB01_normal_walk_1_2-0_moment.csv');
WN20_power = pd.read_csv('/content/drive/My Drive/CS6140_Project/normal_walk_1_2-0/AB01_normal_walk_1_2-0_power.csv');
WN20_velocity = pd.read_csv('/content/drive/My Drive/CS6140_Project/normal_walk_1_2-0/AB01_normal_walk_1_2-0_velocity.csv');

WN25_af = pd.read_csv('/content/drive/My Drive/CS6140_Project/normal_walk_1_2-5/AB01_normal_walk_1_2-5_activity_flag.csv');
WN25_angle = pd.read_csv('/content/drive/My Drive/CS6140_Project/normal_walk_1_2-5/AB01_normal_walk_1_2-5_angle.csv');
WN25_emg = pd.read_csv('/content/drive/My Drive/CS6140_Project/normal_walk_1_2-5/AB01_normal_walk_1_2-5_emg.csv');
WN25_grf = pd.read_csv('/content/drive/My Drive/CS6140_Project/normal_walk_1_2-5/AB01_normal_walk_1_2-5_grf.csv');
WN25_imu_real = pd.read_csv('/content/drive/My Drive/CS6140_Project/normal_walk_1_2-5/AB01_normal_walk_1_2-5_imu_real.csv');
WN25_imu_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/normal_walk_1_2-5/AB01_normal_walk_1_2-5_imu_sim.csv');
WN25_insole_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/normal_walk_1_2-5/AB01_normal_walk_1_2-5_insole_sim.csv');
WN25_moment = pd.read_csv('/content/drive/My Drive/CS6140_Project/normal_walk_1_2-5/AB01_normal_walk_1_2-5_moment.csv');
WN25_power = pd.read_csv('/content/drive/My Drive/CS6140_Project/normal_walk_1_2-5/AB01_normal_walk_1_2-5_power.csv');
WN25_velocity = pd.read_csv('/content/drive/My Drive/CS6140_Project/normal_walk_1_2-5/AB01_normal_walk_1_2-5_velocity.csv');

WNsh_af = pd.read_csv('/content/drive/My Drive/CS6140_Project/normal_walk_1_shuffle/AB01_normal_walk_1_shuffle_activity_flag.csv');
WNsh_angle = pd.read_csv('/content/drive/My Drive/CS6140_Project/normal_walk_1_shuffle/AB01_normal_walk_1_shuffle_angle.csv');
WNsh_emg = pd.read_csv('/content/drive/My Drive/CS6140_Project/normal_walk_1_shuffle/AB01_normal_walk_1_shuffle_emg.csv');
WNsh_grf = pd.read_csv('/content/drive/My Drive/CS6140_Project/normal_walk_1_shuffle/AB01_normal_walk_1_shuffle_grf.csv');
WNsh_imu_real = pd.read_csv('/content/drive/My Drive/CS6140_Project/normal_walk_1_shuffle/AB01_normal_walk_1_shuffle_imu_real.csv');
WNsh_imu_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/normal_walk_1_shuffle/AB01_normal_walk_1_shuffle_imu_sim.csv');
WNsh_insole_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/normal_walk_1_shuffle/AB01_normal_walk_1_shuffle_insole_sim.csv');
WNsh_moment = pd.read_csv('/content/drive/My Drive/CS6140_Project/normal_walk_1_shuffle/AB01_normal_walk_1_shuffle_moment.csv');
WNsh_power = pd.read_csv('/content/drive/My Drive/CS6140_Project/normal_walk_1_shuffle/AB01_normal_walk_1_shuffle_power.csv');
WNsh_velocity = pd.read_csv('/content/drive/My Drive/CS6140_Project/normal_walk_1_shuffle/AB01_normal_walk_1_shuffle_velocity.csv');

WNsk_af = pd.read_csv('/content/drive/My Drive/CS6140_Project/normal_walk_1_skip/AB01_normal_walk_1_skip_activity_flag.csv');
WNsk_angle = pd.read_csv('/content/drive/My Drive/CS6140_Project/normal_walk_1_skip/AB01_normal_walk_1_skip_angle.csv');
WNsk_emg = pd.read_csv('/content/drive/My Drive/CS6140_Project/normal_walk_1_skip/AB01_normal_walk_1_skip_emg.csv');
WNsk_grf = pd.read_csv('/content/drive/My Drive/CS6140_Project/normal_walk_1_skip/AB01_normal_walk_1_skip_grf.csv');
WNsk_imu_real = pd.read_csv('/content/drive/My Drive/CS6140_Project/normal_walk_1_skip/AB01_normal_walk_1_skip_imu_real.csv');
WNsk_imu_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/normal_walk_1_skip/AB01_normal_walk_1_skip_imu_sim.csv');
WNsk_insole_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/normal_walk_1_skip/AB01_normal_walk_1_skip_insole_sim.csv');
WNsk_moment = pd.read_csv('/content/drive/My Drive/CS6140_Project/normal_walk_1_skip/AB01_normal_walk_1_skip_moment.csv');
WNsk_power = pd.read_csv('/content/drive/My Drive/CS6140_Project/normal_walk_1_skip/AB01_normal_walk_1_skip_power.csv');
WNsk_velocity = pd.read_csv('/content/drive/My Drive/CS6140_Project/normal_walk_1_skip/AB01_normal_walk_1_skip_velocity.csv');

WO_af = pd.read_csv('/content/drive/My Drive/CS6140_Project/obstacle_walk_1/AB01_obstacle_walk_1_activity_flag.csv');
WO_angle = pd.read_csv('/content/drive/My Drive/CS6140_Project/obstacle_walk_1/AB01_obstacle_walk_1_angle.csv');
WO_emg = pd.read_csv('/content/drive/My Drive/CS6140_Project/obstacle_walk_1/AB01_obstacle_walk_1_emg.csv');
WO_grf = pd.read_csv('/content/drive/My Drive/CS6140_Project/obstacle_walk_1/AB01_obstacle_walk_1_grf.csv');
WO_imu_real = pd.read_csv('/content/drive/My Drive/CS6140_Project/obstacle_walk_1/AB01_obstacle_walk_1_imu_real.csv');
WO_imu_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/obstacle_walk_1/AB01_obstacle_walk_1_imu_sim.csv');
WO_insole_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/obstacle_walk_1/AB01_obstacle_walk_1_insole_sim.csv');
WO_moment = pd.read_csv('/content/drive/My Drive/CS6140_Project/obstacle_walk_1/AB01_obstacle_walk_1_moment.csv');
WO_power = pd.read_csv('/content/drive/My Drive/CS6140_Project/obstacle_walk_1/AB01_obstacle_walk_1_power.csv');
WO_velocity = pd.read_csv('/content/drive/My Drive/CS6140_Project/obstacle_walk_1/AB01_obstacle_walk_1_velocity.csv');

SS_af = pd.read_csv('/content/drive/My Drive/CS6140_Project/side_shuffle_1/AB01_side_shuffle_1_activity_flag.csv');
SS_angle = pd.read_csv('/content/drive/My Drive/CS6140_Project/side_shuffle_1/AB01_side_shuffle_1_angle.csv');
SS_emg = pd.read_csv('/content/drive/My Drive/CS6140_Project/side_shuffle_1/AB01_side_shuffle_1_emg.csv');
SS_grf = pd.read_csv('/content/drive/My Drive/CS6140_Project/side_shuffle_1/AB01_side_shuffle_1_grf.csv');
SS_imu_real = pd.read_csv('/content/drive/My Drive/CS6140_Project/side_shuffle_1/AB01_side_shuffle_1_imu_real.csv');
SS_imu_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/side_shuffle_1/AB01_side_shuffle_1_imu_sim.csv');
SS_insole_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/side_shuffle_1/AB01_side_shuffle_1_insole_sim.csv');
SS_moment = pd.read_csv('/content/drive/My Drive/CS6140_Project/side_shuffle_1/AB01_side_shuffle_1_moment.csv');
SS_power = pd.read_csv('/content/drive/My Drive/CS6140_Project/side_shuffle_1/AB01_side_shuffle_1_power.csv');
SS_velocity = pd.read_csv('/content/drive/My Drive/CS6140_Project/side_shuffle_1/AB01_side_shuffle_1_velocity.csv');

SQ0_af = pd.read_csv('/content/drive/My Drive/CS6140_Project/squats_1_0lbs/AB01_squats_1_0lbs_activity_flag.csv');
SQ0_angle = pd.read_csv('/content/drive/My Drive/CS6140_Project/squats_1_0lbs/AB01_squats_1_0lbs_angle.csv');
SQ0_emg = pd.read_csv('/content/drive/My Drive/CS6140_Project/squats_1_0lbs/AB01_squats_1_0lbs_emg.csv');
SQ0_grf = pd.read_csv('/content/drive/My Drive/CS6140_Project/squats_1_0lbs/AB01_squats_1_0lbs_grf.csv');
SQ0_imu_real = pd.read_csv('/content/drive/My Drive/CS6140_Project/squats_1_0lbs/AB01_squats_1_0lbs_imu_real.csv');
SQ0_imu_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/squats_1_0lbs/AB01_squats_1_0lbs_imu_sim.csv');
SQ0_insole_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/squats_1_0lbs/AB01_squats_1_0lbs_insole_sim.csv');
SQ0_moment = pd.read_csv('/content/drive/My Drive/CS6140_Project/squats_1_0lbs/AB01_squats_1_0lbs_moment.csv');
SQ0_power = pd.read_csv('/content/drive/My Drive/CS6140_Project/squats_1_0lbs/AB01_squats_1_0lbs_power.csv');
SQ0_velocity = pd.read_csv('/content/drive/My Drive/CS6140_Project/squats_1_0lbs/AB01_squats_1_0lbs_velocity.csv');

SQ25_af = pd.read_csv('/content/drive/My Drive/CS6140_Project/squats_1_25lbs/AB01_squats_1_25lbs_activity_flag.csv');
SQ25_angle = pd.read_csv('/content/drive/My Drive/CS6140_Project/squats_1_25lbs/AB01_squats_1_25lbs_angle.csv');
SQ25_emg = pd.read_csv('/content/drive/My Drive/CS6140_Project/squats_1_25lbs/AB01_squats_1_25lbs_emg.csv');
SQ25_grf = pd.read_csv('/content/drive/My Drive/CS6140_Project/squats_1_25lbs/AB01_squats_1_25lbs_grf.csv');
SQ25_imu_real = pd.read_csv('/content/drive/My Drive/CS6140_Project/squats_1_25lbs/AB01_squats_1_25lbs_imu_real.csv');
SQ25_imu_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/squats_1_25lbs/AB01_squats_1_25lbs_imu_sim.csv');
SQ25_insole_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/squats_1_25lbs/AB01_squats_1_25lbs_insole_sim.csv');
SQ25_moment = pd.read_csv('/content/drive/My Drive/CS6140_Project/squats_1_25lbs/AB01_squats_1_25lbs_moment.csv');
SQ25_power = pd.read_csv('/content/drive/My Drive/CS6140_Project/squats_1_25lbs/AB01_squats_1_25lbs_power.csv');
SQ25_velocity = pd.read_csv('/content/drive/My Drive/CS6140_Project/squats_1_25lbs/AB01_squats_1_25lbs_velocity.csv');

STA1u_af = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_1_up/AB01_stairs_1_1_up_activity_flag.csv');
STA1u_angle = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_1_up/AB01_stairs_1_1_up_angle.csv');
STA1u_emg = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_1_up/AB01_stairs_1_1_up_emg.csv');
STA1u_grf = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_1_up/AB01_stairs_1_1_up_grf.csv');
STA1u_imu_real = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_1_up/AB01_stairs_1_1_up_imu_real.csv');
STA1u_imu_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_1_up/AB01_stairs_1_1_up_imu_sim.csv');
STA1u_insole_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_1_up/AB01_stairs_1_1_up_insole_sim.csv');
STA1u_moment = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_1_up/AB01_stairs_1_1_up_moment.csv');
STA1u_power = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_1_up/AB01_stairs_1_1_up_power.csv');
STA1u_velocity = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_1_up/AB01_stairs_1_1_up_velocity.csv');

STA2d_af = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_2_down/AB01_stairs_1_2_down_activity_flag.csv');
STA2d_angle = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_2_down/AB01_stairs_1_2_down_angle.csv');
STA2d_emg = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_2_down/AB01_stairs_1_2_down_emg.csv');
STA2d_grf = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_2_down/AB01_stairs_1_2_down_grf.csv');
STA2d_imu_real = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_2_down/AB01_stairs_1_2_down_imu_real.csv');
STA2d_imu_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_2_down/AB01_stairs_1_2_down_imu_sim.csv');
STA2d_insole_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_2_down/AB01_stairs_1_2_down_insole_sim.csv');
STA2d_moment = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_2_down/AB01_stairs_1_2_down_moment.csv');
STA2d_power = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_2_down/AB01_stairs_1_2_down_power.csv');
STA2d_velocity = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_2_down/AB01_stairs_1_2_down_velocity.csv');

STA3u_af = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_3_up/AB01_stairs_1_3_up_activity_flag.csv');
STA3u_angle = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_3_up/AB01_stairs_1_3_up_angle.csv');
STA3u_emg = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_3_up/AB01_stairs_1_3_up_emg.csv');
STA3u_grf = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_3_up/AB01_stairs_1_3_up_grf.csv');
STA3u_imu_real = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_3_up/AB01_stairs_1_3_up_imu_real.csv');
STA3u_imu_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_3_up/AB01_stairs_1_3_up_imu_sim.csv');
STA3u_insole_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_3_up/AB01_stairs_1_3_up_insole_sim.csv');
STA3u_moment = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_3_up/AB01_stairs_1_3_up_moment.csv');
STA3u_power = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_3_up/AB01_stairs_1_3_up_power.csv');
STA3u_velocity = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_3_up/AB01_stairs_1_3_up_velocity.csv');

STA4d_af = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_4_down/AB01_stairs_1_4_down_activity_flag.csv');
STA4d_angle = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_4_down/AB01_stairs_1_4_down_angle.csv');
STA4d_emg = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_4_down/AB01_stairs_1_4_down_emg.csv');
STA4d_grf = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_4_down/AB01_stairs_1_4_down_grf.csv');
STA4d_imu_real = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_4_down/AB01_stairs_1_4_down_imu_real.csv');
STA4d_imu_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_4_down/AB01_stairs_1_4_down_imu_sim.csv');
STA4d_insole_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_4_down/AB01_stairs_1_4_down_insole_sim.csv');
STA4d_moment = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_4_down/AB01_stairs_1_4_down_moment.csv');
STA4d_power = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_4_down/AB01_stairs_1_4_down_power.csv');
STA4d_velocity = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_4_down/AB01_stairs_1_4_down_velocity.csv');

STA5u_af = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_5_up/AB01_stairs_1_5_up_activity_flag.csv');
STA5u_angle = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_5_up/AB01_stairs_1_5_up_angle.csv');
STA5u_emg = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_5_up/AB01_stairs_1_5_up_emg.csv');
STA5u_grf = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_5_up/AB01_stairs_1_5_up_grf.csv');
STA5u_imu_real = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_5_up/AB01_stairs_1_5_up_imu_real.csv');
STA5u_imu_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_5_up/AB01_stairs_1_5_up_imu_sim.csv');
STA5u_insole_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_5_up/AB01_stairs_1_5_up_insole_sim.csv');
STA5u_moment = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_5_up/AB01_stairs_1_5_up_moment.csv');
STA5u_power = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_5_up/AB01_stairs_1_5_up_power.csv');
STA5u_velocity = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_5_up/AB01_stairs_1_5_up_velocity.csv');

STA6d_af = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_6_down/AB01_stairs_1_6_down_activity_flag.csv');
STA6d_angle = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_6_down/AB01_stairs_1_6_down_angle.csv');
STA6d_emg = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_6_down/AB01_stairs_1_6_down_emg.csv');
STA6d_grf = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_6_down/AB01_stairs_1_6_down_grf.csv');
STA6d_imu_real = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_6_down/AB01_stairs_1_6_down_imu_real.csv');
STA6d_imu_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_6_down/AB01_stairs_1_6_down_imu_sim.csv');
STA6d_insole_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_6_down/AB01_stairs_1_6_down_insole_sim.csv');
STA6d_moment = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_6_down/AB01_stairs_1_6_down_moment.csv');
STA6d_power = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_6_down/AB01_stairs_1_6_down_power.csv');
STA6d_velocity = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_6_down/AB01_stairs_1_6_down_velocity.csv');

STA7u_af = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_7_up/AB01_stairs_1_7_up_activity_flag.csv');
STA7u_angle = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_7_up/AB01_stairs_1_7_up_angle.csv');
STA7u_emg = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_7_up/AB01_stairs_1_7_up_emg.csv');
STA7u_grf = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_7_up/AB01_stairs_1_7_up_grf.csv');
STA7u_imu_real = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_7_up/AB01_stairs_1_7_up_imu_real.csv');
STA7u_imu_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_7_up/AB01_stairs_1_7_up_imu_sim.csv');
STA7u_insole_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_7_up/AB01_stairs_1_7_up_insole_sim.csv');
STA7u_moment = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_7_up/AB01_stairs_1_7_up_moment.csv');
STA7u_power = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_7_up/AB01_stairs_1_7_up_power.csv');
STA7u_velocity = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_7_up/AB01_stairs_1_7_up_velocity.csv');

STA8d_af = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_8_down/AB01_stairs_1_8_down_activity_flag.csv');
STA8d_angle = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_8_down/AB01_stairs_1_8_down_angle.csv');
STA8d_emg = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_8_down/AB01_stairs_1_8_down_emg.csv');
STA8d_grf = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_8_down/AB01_stairs_1_8_down_grf.csv');
STA8d_imu_real = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_8_down/AB01_stairs_1_8_down_imu_real.csv');
STA8d_imu_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_8_down/AB01_stairs_1_8_down_imu_sim.csv');
STA8d_insole_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_8_down/AB01_stairs_1_8_down_insole_sim.csv');
STA8d_moment = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_8_down/AB01_stairs_1_8_down_moment.csv');
STA8d_power = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_8_down/AB01_stairs_1_8_down_power.csv');
STA8d_velocity = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_8_down/AB01_stairs_1_8_down_velocity.csv');

STA9u_af = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_9_up/AB01_stairs_1_9_up_activity_flag.csv');
STA9u_angle = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_9_up/AB01_stairs_1_9_up_angle.csv');
STA9u_emg = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_9_up/AB01_stairs_1_9_up_emg.csv');
STA9u_grf = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_9_up/AB01_stairs_1_9_up_grf.csv');
STA9u_imu_real = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_9_up/AB01_stairs_1_9_up_imu_real.csv');
STA9u_imu_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_9_up/AB01_stairs_1_9_up_imu_sim.csv');
STA9u_insole_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_9_up/AB01_stairs_1_9_up_insole_sim.csv');
STA9u_moment = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_9_up/AB01_stairs_1_9_up_moment.csv');
STA9u_power = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_9_up/AB01_stairs_1_9_up_power.csv');
STA9u_velocity = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_9_up/AB01_stairs_1_9_up_velocity.csv');

STA10d_af = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_10_down/AB01_stairs_1_10_down_activity_flag.csv');
STA10d_angle = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_10_down/AB01_stairs_1_10_down_angle.csv');
STA10d_emg = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_10_down/AB01_stairs_1_10_down_emg.csv');
STA10d_grf = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_10_down/AB01_stairs_1_10_down_grf.csv');
STA10d_imu_real = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_10_down/AB01_stairs_1_10_down_imu_real.csv');
STA10d_imu_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_10_down/AB01_stairs_1_10_down_imu_sim.csv');
STA10d_insole_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_10_down/AB01_stairs_1_10_down_insole_sim.csv');
STA10d_moment = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_10_down/AB01_stairs_1_10_down_moment.csv');
STA10d_power = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_10_down/AB01_stairs_1_10_down_power.csv');
STA10d_velocity = pd.read_csv('/content/drive/My Drive/CS6140_Project/stairs_1_10_down/AB01_stairs_1_10_down_velocity.csv');

WB06_af = pd.read_csv('/content/drive/My Drive/CS6140_Project/walk_backward_1_0-6/AB01_walk_backward_1_0-6_activity_flag.csv');
WB06_angle = pd.read_csv('/content/drive/My Drive/CS6140_Project/walk_backward_1_0-6/AB01_walk_backward_1_0-6_angle.csv');
WB06_emg = pd.read_csv('/content/drive/My Drive/CS6140_Project/walk_backward_1_0-6/AB01_walk_backward_1_0-6_emg.csv');
WB06_grf = pd.read_csv('/content/drive/My Drive/CS6140_Project/walk_backward_1_0-6/AB01_walk_backward_1_0-6_grf.csv');
WB06_imu_real = pd.read_csv('/content/drive/My Drive/CS6140_Project/walk_backward_1_0-6/AB01_walk_backward_1_0-6_imu_real.csv');
WB06_imu_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/walk_backward_1_0-6/AB01_walk_backward_1_0-6_imu_sim.csv');
WB06_insole_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/walk_backward_1_0-6/AB01_walk_backward_1_0-6_insole_sim.csv');
WB06_moment = pd.read_csv('/content/drive/My Drive/CS6140_Project/walk_backward_1_0-6/AB01_walk_backward_1_0-6_moment.csv');
WB06_power = pd.read_csv('/content/drive/My Drive/CS6140_Project/walk_backward_1_0-6/AB01_walk_backward_1_0-6_power.csv');
WB06_velocity = pd.read_csv('/content/drive/My Drive/CS6140_Project/walk_backward_1_0-6/AB01_walk_backward_1_0-6_velocity.csv');

WB08_af = pd.read_csv('/content/drive/My Drive/CS6140_Project/walk_backward_2_0-8/AB01_walk_backward_2_0-8_activity_flag.csv');
WB08_angle = pd.read_csv('/content/drive/My Drive/CS6140_Project/walk_backward_2_0-8/AB01_walk_backward_2_0-8_angle.csv');
WB08_emg = pd.read_csv('/content/drive/My Drive/CS6140_Project/walk_backward_2_0-8/AB01_walk_backward_2_0-8_emg.csv');
WB08_grf = pd.read_csv('/content/drive/My Drive/CS6140_Project/walk_backward_2_0-8/AB01_walk_backward_2_0-8_grf.csv');
WB08_imu_real = pd.read_csv('/content/drive/My Drive/CS6140_Project/walk_backward_2_0-8/AB01_walk_backward_2_0-8_imu_real.csv');
WB08_imu_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/walk_backward_2_0-8/AB01_walk_backward_2_0-8_imu_sim.csv');
WB08_insole_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/walk_backward_2_0-8/AB01_walk_backward_2_0-8_insole_sim.csv');
WB08_moment = pd.read_csv('/content/drive/My Drive/CS6140_Project/walk_backward_2_0-8/AB01_walk_backward_2_0-8_moment.csv');
WB08_power = pd.read_csv('/content/drive/My Drive/CS6140_Project/walk_backward_2_0-8/AB01_walk_backward_2_0-8_power.csv');
WB08_velocity = pd.read_csv('/content/drive/My Drive/CS6140_Project/walk_backward_2_0-8/AB01_walk_backward_2_0-8_velocity.csv');

WB10_af = pd.read_csv('/content/drive/My Drive/CS6140_Project/walk_backward_2_1-0/AB01_walk_backward_2_1-0_activity_flag.csv');
WB10_angle = pd.read_csv('/content/drive/My Drive/CS6140_Project/walk_backward_2_1-0/AB01_walk_backward_2_1-0_angle.csv');
WB10_emg = pd.read_csv('/content/drive/My Drive/CS6140_Project/walk_backward_2_1-0/AB01_walk_backward_2_1-0_emg.csv');
WB10_grf = pd.read_csv('/content/drive/My Drive/CS6140_Project/walk_backward_2_1-0/AB01_walk_backward_2_1-0_grf.csv');
WB10_imu_real = pd.read_csv('/content/drive/My Drive/CS6140_Project/walk_backward_2_1-0/AB01_walk_backward_2_1-0_imu_real.csv');
WB10_imu_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/walk_backward_2_1-0/AB01_walk_backward_2_1-0_imu_sim.csv');
WB10_insole_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/walk_backward_2_1-0/AB01_walk_backward_2_1-0_insole_sim.csv');
WB10_moment = pd.read_csv('/content/drive/My Drive/CS6140_Project/walk_backward_2_1-0/AB01_walk_backward_2_1-0_moment.csv');
WB10_power = pd.read_csv('/content/drive/My Drive/CS6140_Project/walk_backward_2_1-0/AB01_walk_backward_2_1-0_power.csv');
WB10_velocity = pd.read_csv('/content/drive/My Drive/CS6140_Project/walk_backward_2_1-0/AB01_walk_backward_2_1-0_velocity.csv');

WW25_af = pd.read_csv('/content/drive/My Drive/CS6140_Project/weighted_walk_1_25lbs/AB01_weighted_walk_1_25lbs_activity_flag.csv');
WW25_angle = pd.read_csv('/content/drive/My Drive/CS6140_Project/weighted_walk_1_25lbs/AB01_weighted_walk_1_25lbs_angle.csv');
WW25_emg = pd.read_csv('/content/drive/My Drive/CS6140_Project/weighted_walk_1_25lbs/AB01_weighted_walk_1_25lbs_emg.csv');
WW25_grf = pd.read_csv('/content/drive/My Drive/CS6140_Project/weighted_walk_1_25lbs/AB01_weighted_walk_1_25lbs_grf.csv');
WW25_imu_real = pd.read_csv('/content/drive/My Drive/CS6140_Project/weighted_walk_1_25lbs/AB01_weighted_walk_1_25lbs_imu_real.csv');
WW25_imu_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/weighted_walk_1_25lbs/AB01_weighted_walk_1_25lbs_imu_sim.csv');
WW25_insole_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/weighted_walk_1_25lbs/AB01_weighted_walk_1_25lbs_insole_sim.csv');
WW25_moment = pd.read_csv('/content/drive/My Drive/CS6140_Project/weighted_walk_1_25lbs/AB01_weighted_walk_1_25lbs_moment.csv');
WW25_power = pd.read_csv('/content/drive/My Drive/CS6140_Project/weighted_walk_1_25lbs/AB01_weighted_walk_1_25lbs_power.csv');
WW25_velocity = pd.read_csv('/content/drive/My Drive/CS6140_Project/weighted_walk_1_25lbs/AB01_weighted_walk_1_25lbs_velocity.csv');



# Non-cyclic data:
BTc_af = pd.read_csv('/content/drive/My Drive/CS6140_Project/ball_toss_1_center/AB01_ball_toss_1_center_activity_flag.csv');
BTc_angle = pd.read_csv('/content/drive/My Drive/CS6140_Project/ball_toss_1_center/AB01_ball_toss_1_center_angle.csv');
BTc_emg = pd.read_csv('/content/drive/My Drive/CS6140_Project/ball_toss_1_center/AB01_ball_toss_1_center_emg.csv');
BTc_grf = pd.read_csv('/content/drive/My Drive/CS6140_Project/ball_toss_1_center/AB01_ball_toss_1_center_grf.csv');
BTc_imu_real = pd.read_csv('/content/drive/My Drive/CS6140_Project/ball_toss_1_center/AB01_ball_toss_1_center_imu_real.csv');
BTc_imu_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/ball_toss_1_center/AB01_ball_toss_1_center_imu_sim.csv');
BTc_insole_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/ball_toss_1_center/AB01_ball_toss_1_center_insole_sim.csv');
BTc_moment = pd.read_csv('/content/drive/My Drive/CS6140_Project/ball_toss_1_center/AB01_ball_toss_1_center_moment.csv');
BTc_power = pd.read_csv('/content/drive/My Drive/CS6140_Project/ball_toss_1_center/AB01_ball_toss_1_center_power.csv');
BTc_velocity = pd.read_csv('/content/drive/My Drive/CS6140_Project/ball_toss_1_center/AB01_ball_toss_1_center_velocity.csv');

BTl_af = pd.read_csv('/content/drive/My Drive/CS6140_Project/ball_toss_1_left/AB01_ball_toss_1_left_activity_flag.csv');
BTl_angle = pd.read_csv('/content/drive/My Drive/CS6140_Project/ball_toss_1_left/AB01_ball_toss_1_left_angle.csv');
BTl_emg = pd.read_csv('/content/drive/My Drive/CS6140_Project/ball_toss_1_left/AB01_ball_toss_1_left_emg.csv');
BTl_grf = pd.read_csv('/content/drive/My Drive/CS6140_Project/ball_toss_1_left/AB01_ball_toss_1_left_grf.csv');
BTl_imu_real = pd.read_csv('/content/drive/My Drive/CS6140_Project/ball_toss_1_left/AB01_ball_toss_1_left_imu_real.csv');
BTl_imu_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/ball_toss_1_left/AB01_ball_toss_1_left_imu_sim.csv');
BTl_insole_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/ball_toss_1_left/AB01_ball_toss_1_left_insole_sim.csv');
BTl_moment = pd.read_csv('/content/drive/My Drive/CS6140_Project/ball_toss_1_left/AB01_ball_toss_1_left_moment.csv');
BTl_power = pd.read_csv('/content/drive/My Drive/CS6140_Project/ball_toss_1_left/AB01_ball_toss_1_left_power.csv');
BTl_velocity = pd.read_csv('/content/drive/My Drive/CS6140_Project/ball_toss_1_left/AB01_ball_toss_1_left_velocity.csv');

BTr_af = pd.read_csv('/content/drive/My Drive/CS6140_Project/ball_toss_1_right/AB01_ball_toss_1_right_activity_flag.csv');
BTr_angle = pd.read_csv('/content/drive/My Drive/CS6140_Project/ball_toss_1_right/AB01_ball_toss_1_right_angle.csv');
BTr_emg = pd.read_csv('/content/drive/My Drive/CS6140_Project/ball_toss_1_right/AB01_ball_toss_1_right_emg.csv');
BTr_grf = pd.read_csv('/content/drive/My Drive/CS6140_Project/ball_toss_1_right/AB01_ball_toss_1_right_grf.csv');
BTr_imu_real = pd.read_csv('/content/drive/My Drive/CS6140_Project/ball_toss_1_right/AB01_ball_toss_1_right_imu_real.csv');
BTr_imu_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/ball_toss_1_right/AB01_ball_toss_1_right_imu_sim.csv');
BTr_insole_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/ball_toss_1_right/AB01_ball_toss_1_right_insole_sim.csv');
BTr_moment = pd.read_csv('/content/drive/My Drive/CS6140_Project/ball_toss_1_right/AB01_ball_toss_1_right_moment.csv');
BTr_power = pd.read_csv('/content/drive/My Drive/CS6140_Project/ball_toss_1_right/AB01_ball_toss_1_right_power.csv');
BTr_velocity = pd.read_csv('/content/drive/My Drive/CS6140_Project/ball_toss_1_right/AB01_ball_toss_1_right_velocity.csv');

CURd_af = pd.read_csv('/content/drive/My Drive/CS6140_Project/curb_down_1/AB01_curb_down_1_activity_flag.csv');
CURd_angle = pd.read_csv('/content/drive/My Drive/CS6140_Project/curb_down_1/AB01_curb_down_1_angle.csv');
CURd_emg = pd.read_csv('/content/drive/My Drive/CS6140_Project/curb_down_1/AB01_curb_down_1_emg.csv');
CURd_grf = pd.read_csv('/content/drive/My Drive/CS6140_Project/curb_down_1/AB01_curb_down_1_grf.csv');
CURd_imu_real = pd.read_csv('/content/drive/My Drive/CS6140_Project/curb_down_1/AB01_curb_down_1_imu_real.csv');
CURd_imu_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/curb_down_1/AB01_curb_down_1_imu_sim.csv');
CURd_insole_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/curb_down_1/AB01_curb_down_1_insole_sim.csv');
CURd_moment = pd.read_csv('/content/drive/My Drive/CS6140_Project/curb_down_1/AB01_curb_down_1_moment.csv');
CURd_power = pd.read_csv('/content/drive/My Drive/CS6140_Project/curb_down_1/AB01_curb_down_1_power.csv');
CURd_velocity = pd.read_csv('/content/drive/My Drive/CS6140_Project/curb_down_1/AB01_curb_down_1_velocity.csv');

CURu_af = pd.read_csv('/content/drive/My Drive/CS6140_Project/curb_up_1/AB01_curb_up_1_activity_flag.csv');
CURu_angle = pd.read_csv('/content/drive/My Drive/CS6140_Project/curb_up_1/AB01_curb_up_1_angle.csv');
CURu_emg = pd.read_csv('/content/drive/My Drive/CS6140_Project/curb_up_1/AB01_curb_up_1_emg.csv');
CURu_grf = pd.read_csv('/content/drive/My Drive/CS6140_Project/curb_up_1/AB01_curb_up_1_grf.csv');
CURu_imu_real = pd.read_csv('/content/drive/My Drive/CS6140_Project/curb_up_1/AB01_curb_up_1_imu_real.csv');
CURu_imu_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/curb_up_1/AB01_curb_up_1_imu_sim.csv');
CURu_insole_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/curb_up_1/AB01_curb_up_1_insole_sim.csv');
CURu_moment = pd.read_csv('/content/drive/My Drive/CS6140_Project/curb_up_1/AB01_curb_up_1_moment.csv');
CURu_power = pd.read_csv('/content/drive/My Drive/CS6140_Project/curb_up_1/AB01_curb_up_1_power.csv');
CURu_velocity = pd.read_csv('/content/drive/My Drive/CS6140_Project/curb_up_1/AB01_curb_up_1_velocity.csv');

CUTlf_af = pd.read_csv('/content/drive/My Drive/CS6140_Project/cutting_1_left-fast/AB01_cutting_1_left-fast_activity_flag.csv');
CUTlf_angle = pd.read_csv('/content/drive/My Drive/CS6140_Project/cutting_1_left-fast/AB01_cutting_1_left-fast_angle.csv');
CUTlf_emg = pd.read_csv('/content/drive/My Drive/CS6140_Project/cutting_1_left-fast/AB01_cutting_1_left-fast_emg.csv');
CUTlf_grf = pd.read_csv('/content/drive/My Drive/CS6140_Project/cutting_1_left-fast/AB01_cutting_1_left-fast_grf.csv');
CUTlf_imu_real = pd.read_csv('/content/drive/My Drive/CS6140_Project/cutting_1_left-fast/AB01_cutting_1_left-fast_imu_real.csv');
CUTlf_imu_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/cutting_1_left-fast/AB01_cutting_1_left-fast_imu_sim.csv');
CUTlf_insole_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/cutting_1_left-fast/AB01_cutting_1_left-fast_insole_sim.csv');
CUTlf_moment = pd.read_csv('/content/drive/My Drive/CS6140_Project/cutting_1_left-fast/AB01_cutting_1_left-fast_moment.csv');
CUTlf_power = pd.read_csv('/content/drive/My Drive/CS6140_Project/cutting_1_left-fast/AB01_cutting_1_left-fast_power.csv');
CUTlf_velocity = pd.read_csv('/content/drive/My Drive/CS6140_Project/cutting_1_left-fast/AB01_cutting_1_left-fast_velocity.csv');

CUTls_af = pd.read_csv('/content/drive/My Drive/CS6140_Project/cutting_1_left-slow/AB01_cutting_1_left-slow_activity_flag.csv');
CUTls_angle = pd.read_csv('/content/drive/My Drive/CS6140_Project/cutting_1_left-slow/AB01_cutting_1_left-slow_angle.csv');
CUTls_emg = pd.read_csv('/content/drive/My Drive/CS6140_Project/cutting_1_left-slow/AB01_cutting_1_left-slow_emg.csv');
CUTls_grf = pd.read_csv('/content/drive/My Drive/CS6140_Project/cutting_1_left-slow/AB01_cutting_1_left-slow_grf.csv');
CUTls_imu_real = pd.read_csv('/content/drive/My Drive/CS6140_Project/cutting_1_left-slow/AB01_cutting_1_left-slow_imu_real.csv');
CUTls_imu_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/cutting_1_left-slow/AB01_cutting_1_left-slow_imu_sim.csv');
CUTls_insole_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/cutting_1_left-slow/AB01_cutting_1_left-slow_insole_sim.csv');
CUTls_moment = pd.read_csv('/content/drive/My Drive/CS6140_Project/cutting_1_left-slow/AB01_cutting_1_left-slow_moment.csv');
CUTls_power = pd.read_csv('/content/drive/My Drive/CS6140_Project/cutting_1_left-slow/AB01_cutting_1_left-slow_power.csv');
CUTls_velocity = pd.read_csv('/content/drive/My Drive/CS6140_Project/cutting_1_left-slow/AB01_cutting_1_left-slow_velocity.csv');

CUTrf_af = pd.read_csv('/content/drive/My Drive/CS6140_Project/cutting_1_right-fast/AB01_cutting_1_right-fast_activity_flag.csv');
CUTrf_angle = pd.read_csv('/content/drive/My Drive/CS6140_Project/cutting_1_right-fast/AB01_cutting_1_right-fast_angle.csv');
CUTrf_emg = pd.read_csv('/content/drive/My Drive/CS6140_Project/cutting_1_right-fast/AB01_cutting_1_right-fast_emg.csv');
CUTrf_grf = pd.read_csv('/content/drive/My Drive/CS6140_Project/cutting_1_right-fast/AB01_cutting_1_right-fast_grf.csv');
CUTrf_imu_real = pd.read_csv('/content/drive/My Drive/CS6140_Project/cutting_1_right-fast/AB01_cutting_1_right-fast_imu_real.csv');
CUTrf_imu_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/cutting_1_right-fast/AB01_cutting_1_right-fast_imu_sim.csv');
CUTrf_insole_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/cutting_1_right-fast/AB01_cutting_1_right-fast_insole_sim.csv');
CUTrf_moment = pd.read_csv('/content/drive/My Drive/CS6140_Project/cutting_1_right-fast/AB01_cutting_1_right-fast_moment.csv');
CUTrf_power = pd.read_csv('/content/drive/My Drive/CS6140_Project/cutting_1_right-fast/AB01_cutting_1_right-fast_power.csv');
CUTrf_velocity = pd.read_csv('/content/drive/My Drive/CS6140_Project/cutting_1_right-fast/AB01_cutting_1_right-fast_velocity.csv');

CUTrs_af = pd.read_csv('/content/drive/My Drive/CS6140_Project/cutting_1_right-slow/AB01_cutting_1_right-slow_activity_flag.csv');
CUTrs_angle = pd.read_csv('/content/drive/My Drive/CS6140_Project/cutting_1_right-slow/AB01_cutting_1_right-slow_angle.csv');
CUTrs_emg = pd.read_csv('/content/drive/My Drive/CS6140_Project/cutting_1_right-slow/AB01_cutting_1_right-slow_emg.csv');
CUTrs_grf = pd.read_csv('/content/drive/My Drive/CS6140_Project/cutting_1_right-slow/AB01_cutting_1_right-slow_grf.csv');
CUTrs_imu_real = pd.read_csv('/content/drive/My Drive/CS6140_Project/cutting_1_right-slow/AB01_cutting_1_right-slow_imu_real.csv');
CUTrs_imu_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/cutting_1_right-slow/AB01_cutting_1_right-slow_imu_sim.csv');
CUTrs_insole_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/cutting_1_right-slow/AB01_cutting_1_right-slow_insole_sim.csv');
CUTrs_moment = pd.read_csv('/content/drive/My Drive/CS6140_Project/cutting_1_right-slow/AB01_cutting_1_right-slow_moment.csv');
CUTrs_power = pd.read_csv('/content/drive/My Drive/CS6140_Project/cutting_1_right-slow/AB01_cutting_1_right-slow_power.csv');
CUTrs_velocity = pd.read_csv('/content/drive/My Drive/CS6140_Project/cutting_1_right-slow/AB01_cutting_1_right-slow_velocity.csv');

JUfb_af = pd.read_csv('/content/drive/My Drive/CS6140_Project/jump_1_fb/AB01_jump_1_fb_activity_flag.csv');
JUfb_angle = pd.read_csv('/content/drive/My Drive/CS6140_Project/jump_1_fb/AB01_jump_1_fb_angle.csv');
JUfb_emg = pd.read_csv('/content/drive/My Drive/CS6140_Project/jump_1_fb/AB01_jump_1_fb_emg.csv');
JUfb_grf = pd.read_csv('/content/drive/My Drive/CS6140_Project/jump_1_fb/AB01_jump_1_fb_grf.csv');
JUfb_imu_real = pd.read_csv('/content/drive/My Drive/CS6140_Project/jump_1_fb/AB01_jump_1_fb_imu_real.csv');
JUfb_imu_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/jump_1_fb/AB01_jump_1_fb_imu_sim.csv');
JUfb_insole_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/jump_1_fb/AB01_jump_1_fb_insole_sim.csv');
JUfb_moment = pd.read_csv('/content/drive/My Drive/CS6140_Project/jump_1_fb/AB01_jump_1_fb_moment.csv');
JUfb_power = pd.read_csv('/content/drive/My Drive/CS6140_Project/jump_1_fb/AB01_jump_1_fb_power.csv');
JUfb_velocity = pd.read_csv('/content/drive/My Drive/CS6140_Project/jump_1_fb/AB01_jump_1_fb_velocity.csv');

JUh_af = pd.read_csv('/content/drive/My Drive/CS6140_Project/jump_1_hop/AB01_jump_1_hop_activity_flag.csv');
JUh_angle = pd.read_csv('/content/drive/My Drive/CS6140_Project/jump_1_hop/AB01_jump_1_hop_angle.csv');
JUh_emg = pd.read_csv('/content/drive/My Drive/CS6140_Project/jump_1_hop/AB01_jump_1_hop_emg.csv');
JUh_grf = pd.read_csv('/content/drive/My Drive/CS6140_Project/jump_1_hop/AB01_jump_1_hop_grf.csv');
JUh_imu_real = pd.read_csv('/content/drive/My Drive/CS6140_Project/jump_1_hop/AB01_jump_1_hop_imu_real.csv');
JUh_imu_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/jump_1_hop/AB01_jump_1_hop_imu_sim.csv');
JUh_insole_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/jump_1_hop/AB01_jump_1_hop_insole_sim.csv');
JUh_moment = pd.read_csv('/content/drive/My Drive/CS6140_Project/jump_1_hop/AB01_jump_1_hop_moment.csv');
JUh_power = pd.read_csv('/content/drive/My Drive/CS6140_Project/jump_1_hop/AB01_jump_1_hop_power.csv');
JUh_velocity = pd.read_csv('/content/drive/My Drive/CS6140_Project/jump_1_hop/AB01_jump_1_hop_velocity.csv');

JUfv_af = pd.read_csv('/content/drive/My Drive/CS6140_Project/jump_1_vertical/AB01_jump_1_vertical_activity_flag.csv');
JUfv_angle = pd.read_csv('/content/drive/My Drive/CS6140_Project/jump_1_vertical/AB01_jump_1_vertical_angle.csv');
JUfv_emg = pd.read_csv('/content/drive/My Drive/CS6140_Project/jump_1_vertical/AB01_jump_1_vertical_emg.csv');
JUfv_grf = pd.read_csv('/content/drive/My Drive/CS6140_Project/jump_1_vertical/AB01_jump_1_vertical_grf.csv');
JUfv_imu_real = pd.read_csv('/content/drive/My Drive/CS6140_Project/jump_1_vertical/AB01_jump_1_vertical_imu_real.csv');
JUfv_imu_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/jump_1_vertical/AB01_jump_1_vertical_imu_sim.csv');
JUfv_insole_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/jump_1_vertical/AB01_jump_1_vertical_insole_sim.csv');
JUfv_moment = pd.read_csv('/content/drive/My Drive/CS6140_Project/jump_1_vertical/AB01_jump_1_vertical_moment.csv');
JUfv_power = pd.read_csv('/content/drive/My Drive/CS6140_Project/jump_1_vertical/AB01_jump_1_vertical_power.csv');
JUfv_velocity = pd.read_csv('/content/drive/My Drive/CS6140_Project/jump_1_vertical/AB01_jump_1_vertical_velocity.csv');

JU901_af = pd.read_csv('/content/drive/My Drive/CS6140_Project/jump_2_90-1/AB01_jump_2_90-1_activity_flag.csv');
JU901_angle = pd.read_csv('/content/drive/My Drive/CS6140_Project/jump_2_90-1/AB01_jump_2_90-1_angle.csv');
JU901_emg = pd.read_csv('/content/drive/My Drive/CS6140_Project/jump_2_90-1/AB01_jump_2_90-1_emg.csv');
JU901_grf = pd.read_csv('/content/drive/My Drive/CS6140_Project/jump_2_90-1/AB01_jump_2_90-1_grf.csv');
JU901_imu_real = pd.read_csv('/content/drive/My Drive/CS6140_Project/jump_2_90-1/AB01_jump_2_90-1_imu_real.csv');
JU901_imu_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/jump_2_90-1/AB01_jump_2_90-1_imu_sim.csv');
JU901_insole_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/jump_2_90-1/AB01_jump_2_90-1_insole_sim.csv');
JU901_moment = pd.read_csv('/content/drive/My Drive/CS6140_Project/jump_2_90-1/AB01_jump_2_90-1_moment.csv');
JU901_power = pd.read_csv('/content/drive/My Drive/CS6140_Project/jump_2_90-1/AB01_jump_2_90-1_power.csv');
JU901_velocity = pd.read_csv('/content/drive/My Drive/CS6140_Project/jump_2_90-1/AB01_jump_2_90-1_velocity.csv');

JU902_af = pd.read_csv('/content/drive/My Drive/CS6140_Project/jump_2_90-2/AB01_jump_2_90-2_activity_flag.csv');
JU902_angle = pd.read_csv('/content/drive/My Drive/CS6140_Project/jump_2_90-2/AB01_jump_2_90-2_angle.csv');
JU902_emg = pd.read_csv('/content/drive/My Drive/CS6140_Project/jump_2_90-2/AB01_jump_2_90-2_emg.csv');
JU902_grf = pd.read_csv('/content/drive/My Drive/CS6140_Project/jump_2_90-2/AB01_jump_2_90-2_grf.csv');
JU902_imu_real = pd.read_csv('/content/drive/My Drive/CS6140_Project/jump_2_90-2/AB01_jump_2_90-2_imu_real.csv');
JU902_imu_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/jump_2_90-2/AB01_jump_2_90-2_imu_sim.csv');
JU902_insole_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/jump_2_90-2/AB01_jump_2_90-2_insole_sim.csv');
JU902_moment = pd.read_csv('/content/drive/My Drive/CS6140_Project/jump_2_90-2/AB01_jump_2_90-2_moment.csv');
JU902_power = pd.read_csv('/content/drive/My Drive/CS6140_Project/jump_2_90-2/AB01_jump_2_90-2_power.csv');
JU902_velocity = pd.read_csv('/content/drive/My Drive/CS6140_Project/jump_2_90-2/AB01_jump_2_90-2_velocity.csv');

JU180_af = pd.read_csv('/content/drive/My Drive/CS6140_Project/jump_2_180/AB01_jump_2_180_activity_flag.csv');
JU180_angle = pd.read_csv('/content/drive/My Drive/CS6140_Project/jump_2_180/AB01_jump_2_180_angle.csv');
JU180_emg = pd.read_csv('/content/drive/My Drive/CS6140_Project/jump_2_180/AB01_jump_2_180_emg.csv');
JU180_grf = pd.read_csv('/content/drive/My Drive/CS6140_Project/jump_2_180/AB01_jump_2_180_grf.csv');
JU180_imu_real = pd.read_csv('/content/drive/My Drive/CS6140_Project/jump_2_180/AB01_jump_2_180_imu_real.csv');
JU180_imu_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/jump_2_180/AB01_jump_2_180_imu_sim.csv');
JU180_insole_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/jump_2_180/AB01_jump_2_180_insole_sim.csv');
JU180_moment = pd.read_csv('/content/drive/My Drive/CS6140_Project/jump_2_180/AB01_jump_2_180_moment.csv');
JU180_power = pd.read_csv('/content/drive/My Drive/CS6140_Project/jump_2_180/AB01_jump_2_180_power.csv');
JU180_velocity = pd.read_csv('/content/drive/My Drive/CS6140_Project/jump_2_180/AB01_jump_2_180_velocity.csv');

JUl_af = pd.read_csv('/content/drive/My Drive/CS6140_Project/jump_2_lateral/AB01_jump_2_lateral_activity_flag.csv');
JUl_angle = pd.read_csv('/content/drive/My Drive/CS6140_Project/jump_2_lateral/AB01_jump_2_lateral_angle.csv');
JUl_emg = pd.read_csv('/content/drive/My Drive/CS6140_Project/jump_2_lateral/AB01_jump_2_lateral_emg.csv');
JUl_grf = pd.read_csv('/content/drive/My Drive/CS6140_Project/jump_2_lateral/AB01_jump_2_lateral_grf.csv');
JUl_imu_real = pd.read_csv('/content/drive/My Drive/CS6140_Project/jump_2_lateral/AB01_jump_2_lateral_imu_real.csv');
JUl_imu_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/jump_2_lateral/AB01_jump_2_lateral_imu_sim.csv');
JUl_insole_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/jump_2_lateral/AB01_jump_2_lateral_insole_sim.csv');
JUl_moment = pd.read_csv('/content/drive/My Drive/CS6140_Project/jump_2_lateral/AB01_jump_2_lateral_moment.csv');
JUl_power = pd.read_csv('/content/drive/My Drive/CS6140_Project/jump_2_lateral/AB01_jump_2_lateral_power.csv');
JUl_velocity = pd.read_csv('/content/drive/My Drive/CS6140_Project/jump_2_lateral/AB01_jump_2_lateral_velocity.csv');

LW25lc_af = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_1_25lbs-l-c/AB01_lift_weight_1_25lbs-l-c_activity_flag.csv');
LW25lc_angle = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_1_25lbs-l-c/AB01_lift_weight_1_25lbs-l-c_angle.csv');
LW25lc_emg = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_1_25lbs-l-c/AB01_lift_weight_1_25lbs-l-c_emg.csv');
LW25lc_grf = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_1_25lbs-l-c/AB01_lift_weight_1_25lbs-l-c_grf.csv');
LW25lc_imu_real = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_1_25lbs-l-c/AB01_lift_weight_1_25lbs-l-c_imu_real.csv');
LW25lc_imu_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_1_25lbs-l-c/AB01_lift_weight_1_25lbs-l-c_imu_sim.csv');
LW25lc_insole_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_1_25lbs-l-c/AB01_lift_weight_1_25lbs-l-c_insole_sim.csv');
LW25lc_moment = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_1_25lbs-l-c/AB01_lift_weight_1_25lbs-l-c_moment.csv');
LW25lc_power = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_1_25lbs-l-c/AB01_lift_weight_1_25lbs-l-c_power.csv');
LW25lc_velocity = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_1_25lbs-l-c/AB01_lift_weight_1_25lbs-l-c_velocity.csv');

LW25ll_af = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_1_25lbs-l-l/AB01_lift_weight_1_25lbs-l-l_activity_flag.csv');
LW25ll_angle = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_1_25lbs-l-l/AB01_lift_weight_1_25lbs-l-l_angle.csv');
LW25ll_emg = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_1_25lbs-l-l/AB01_lift_weight_1_25lbs-l-l_emg.csv');
LW25ll_grf = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_1_25lbs-l-l/AB01_lift_weight_1_25lbs-l-l_grf.csv');
LW25ll_imu_real = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_1_25lbs-l-l/AB01_lift_weight_1_25lbs-l-l_imu_real.csv');
LW25ll_imu_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_1_25lbs-l-l/AB01_lift_weight_1_25lbs-l-l_imu_sim.csv');
LW25ll_insole_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_1_25lbs-l-l/AB01_lift_weight_1_25lbs-l-l_insole_sim.csv');
LW25ll_moment = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_1_25lbs-l-l/AB01_lift_weight_1_25lbs-l-l_moment.csv');
LW25ll_power = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_1_25lbs-l-l/AB01_lift_weight_1_25lbs-l-l_power.csv');
LW25ll_velocity = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_1_25lbs-l-l/AB01_lift_weight_1_25lbs-l-l_velocity.csv');

LW25rc_af = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_1_25lbs-r-c/AB01_lift_weight_1_25lbs-r-c_activity_flag.csv');
LW25rc_angle = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_1_25lbs-r-c/AB01_lift_weight_1_25lbs-r-c_angle.csv');
LW25rc_emg = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_1_25lbs-r-c/AB01_lift_weight_1_25lbs-r-c_emg.csv');
LW25rc_grf = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_1_25lbs-r-c/AB01_lift_weight_1_25lbs-r-c_grf.csv');
LW25rc_imu_real = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_1_25lbs-r-c/AB01_lift_weight_1_25lbs-r-c_imu_real.csv');
LW25rc_imu_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_1_25lbs-r-c/AB01_lift_weight_1_25lbs-r-c_imu_sim.csv');
LW25rc_insole_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_1_25lbs-r-c/AB01_lift_weight_1_25lbs-r-c_insole_sim.csv');
LW25rc_moment = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_1_25lbs-r-c/AB01_lift_weight_1_25lbs-r-c_moment.csv');
LW25rc_power = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_1_25lbs-r-c/AB01_lift_weight_1_25lbs-r-c_power.csv');
LW25rc_velocity = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_1_25lbs-r-c/AB01_lift_weight_1_25lbs-r-c_velocity.csv');

LW25rr_af = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_1_25lbs-r-r/AB01_lift_weight_1_25lbs-r-r_activity_flag.csv');
LW25rr_angle = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_1_25lbs-r-r/AB01_lift_weight_1_25lbs-r-r_angle.csv');
LW25rr_emg = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_1_25lbs-r-r/AB01_lift_weight_1_25lbs-r-r_emg.csv');
LW25rr_grf = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_1_25lbs-r-r/AB01_lift_weight_1_25lbs-r-r_grf.csv');
LW25rr_imu_real = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_1_25lbs-r-r/AB01_lift_weight_1_25lbs-r-r_imu_real.csv');
LW25rr_imu_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_1_25lbs-r-r/AB01_lift_weight_1_25lbs-r-r_imu_sim.csv');
LW25rr_insole_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_1_25lbs-r-r/AB01_lift_weight_1_25lbs-r-r_insole_sim.csv');
LW25rr_moment = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_1_25lbs-r-r/AB01_lift_weight_1_25lbs-r-r_moment.csv');
LW25rr_power = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_1_25lbs-r-r/AB01_lift_weight_1_25lbs-r-r_power.csv');
LW25rr_velocity = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_1_25lbs-r-r/AB01_lift_weight_1_25lbs-r-r_velocity.csv');

LW0lc_af = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_2_0lbs-l-c/AB01_lift_weight_2_0lbs-l-c_activity_flag.csv');
LW0lc_angle = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_2_0lbs-l-c/AB01_lift_weight_2_0lbs-l-c_angle.csv');
LW0lc_emg = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_2_0lbs-l-c/AB01_lift_weight_2_0lbs-l-c_emg.csv');
LW0lc_grf = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_2_0lbs-l-c/AB01_lift_weight_2_0lbs-l-c_grf.csv');
LW0lc_imu_real = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_2_0lbs-l-c/AB01_lift_weight_2_0lbs-l-c_imu_real.csv');
LW0lc_imu_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_2_0lbs-l-c/AB01_lift_weight_2_0lbs-l-c_imu_sim.csv');
LW0lc_insole_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_2_0lbs-l-c/AB01_lift_weight_2_0lbs-l-c_insole_sim.csv');
LW0lc_moment = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_2_0lbs-l-c/AB01_lift_weight_2_0lbs-l-c_moment.csv');
LW0lc_power = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_2_0lbs-l-c/AB01_lift_weight_2_0lbs-l-c_power.csv');
LW0lc_velocity = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_2_0lbs-l-c/AB01_lift_weight_2_0lbs-l-c_velocity.csv');

LW0ll_af = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_2_0lbs-l-l/AB01_lift_weight_2_0lbs-l-l_activity_flag.csv');
LW0ll_angle = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_2_0lbs-l-l/AB01_lift_weight_2_0lbs-l-l_angle.csv');
LW0ll_emg = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_2_0lbs-l-l/AB01_lift_weight_2_0lbs-l-l_emg.csv');
LW0ll_grf = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_2_0lbs-l-l/AB01_lift_weight_2_0lbs-l-l_grf.csv');
LW0ll_imu_real = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_2_0lbs-l-l/AB01_lift_weight_2_0lbs-l-l_imu_real.csv');
LW0ll_imu_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_2_0lbs-l-l/AB01_lift_weight_2_0lbs-l-l_imu_sim.csv');
LW0ll_insole_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_2_0lbs-l-l/AB01_lift_weight_2_0lbs-l-l_insole_sim.csv');
LW0ll_moment = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_2_0lbs-l-l/AB01_lift_weight_2_0lbs-l-l_moment.csv');
LW0ll_power = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_2_0lbs-l-l/AB01_lift_weight_2_0lbs-l-l_power.csv');
LW0ll_velocity = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_2_0lbs-l-l/AB01_lift_weight_2_0lbs-l-l_velocity.csv');

LW0rc_af = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_2_0lbs-r-c/AB01_lift_weight_2_0lbs-r-c_activity_flag.csv');
LW0rc_angle = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_2_0lbs-r-c/AB01_lift_weight_2_0lbs-r-c_angle.csv');
LW0rc_emg = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_2_0lbs-r-c/AB01_lift_weight_2_0lbs-r-c_emg.csv');
LW0rc_grf = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_2_0lbs-r-c/AB01_lift_weight_2_0lbs-r-c_grf.csv');
LW0rc_imu_real = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_2_0lbs-r-c/AB01_lift_weight_2_0lbs-r-c_imu_real.csv');
LW0rc_imu_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_2_0lbs-r-c/AB01_lift_weight_2_0lbs-r-c_imu_sim.csv');
LW0rc_insole_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_2_0lbs-r-c/AB01_lift_weight_2_0lbs-r-c_insole_sim.csv');
LW0rc_moment = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_2_0lbs-r-c/AB01_lift_weight_2_0lbs-r-c_moment.csv');
LW0rc_power = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_2_0lbs-r-c/AB01_lift_weight_2_0lbs-r-c_power.csv');
LW0rc_velocity = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_2_0lbs-r-c/AB01_lift_weight_2_0lbs-r-c_velocity.csv');

LW0rr_af = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_2_0lbs-r-r/AB01_lift_weight_2_0lbs-r-r_activity_flag.csv');
LW0rr_angle = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_2_0lbs-r-r/AB01_lift_weight_2_0lbs-r-r_angle.csv');
LW0rr_emg = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_2_0lbs-r-r/AB01_lift_weight_2_0lbs-r-r_emg.csv');
LW0rr_grf = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_2_0lbs-r-r/AB01_lift_weight_2_0lbs-r-r_grf.csv');
LW0rr_imu_real = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_2_0lbs-r-r/AB01_lift_weight_2_0lbs-r-r_imu_real.csv');
LW0rr_imu_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_2_0lbs-r-r/AB01_lift_weight_2_0lbs-r-r_imu_sim.csv');
LW0rr_insole_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_2_0lbs-r-r/AB01_lift_weight_2_0lbs-r-r_insole_sim.csv');
LW0rr_moment = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_2_0lbs-r-r/AB01_lift_weight_2_0lbs-r-r_moment.csv');
LW0rr_power = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_2_0lbs-r-r/AB01_lift_weight_2_0lbs-r-r_power.csv');
LW0rr_velocity = pd.read_csv('/content/drive/My Drive/CS6140_Project/lift_weight_2_0lbs-r-r/AB01_lift_weight_2_0lbs-r-r_velocity.csv');

LU1_af = pd.read_csv('/content/drive/My Drive/CS6140_Project/lunges_1/AB01_lunges_1_activity_flag.csv');
LU1_angle = pd.read_csv('/content/drive/My Drive/CS6140_Project/lunges_1/AB01_lunges_1_angle.csv');
LU1_emg = pd.read_csv('/content/drive/My Drive/CS6140_Project/lunges_1/AB01_lunges_1_emg.csv');
LU1_grf = pd.read_csv('/content/drive/My Drive/CS6140_Project/lunges_1/AB01_lunges_1_grf.csv');
LU1_imu_real = pd.read_csv('/content/drive/My Drive/CS6140_Project/lunges_1/AB01_lunges_1_imu_real.csv');
LU1_imu_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/lunges_1/AB01_lunges_1_imu_sim.csv');
LU1_insole_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/lunges_1/AB01_lunges_1_insole_sim.csv');
LU1_moment = pd.read_csv('/content/drive/My Drive/CS6140_Project/lunges_1/AB01_lunges_1_moment.csv');
LU1_power = pd.read_csv('/content/drive/My Drive/CS6140_Project/lunges_1/AB01_lunges_1_power.csv');
LU1_velocity = pd.read_csv('/content/drive/My Drive/CS6140_Project/lunges_1/AB01_lunges_1_velocity.csv');

LU2l_af = pd.read_csv('/content/drive/My Drive/CS6140_Project/lunges_2_left/AB01_lunges_2_left_activity_flag.csv');
LU2l_angle = pd.read_csv('/content/drive/My Drive/CS6140_Project/lunges_2_left/AB01_lunges_2_left_angle.csv');
LU2l_emg = pd.read_csv('/content/drive/My Drive/CS6140_Project/lunges_2_left/AB01_lunges_2_left_emg.csv');
LU2l_grf = pd.read_csv('/content/drive/My Drive/CS6140_Project/lunges_2_left/AB01_lunges_2_left_grf.csv');
LU2l_imu_real = pd.read_csv('/content/drive/My Drive/CS6140_Project/lunges_2_left/AB01_lunges_2_left_imu_real.csv');
LU2l_imu_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/lunges_2_left/AB01_lunges_2_left_imu_sim.csv');
LU2l_insole_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/lunges_2_left/AB01_lunges_2_left_insole_sim.csv');
LU2l_moment = pd.read_csv('/content/drive/My Drive/CS6140_Project/lunges_2_left/AB01_lunges_2_left_moment.csv');
LU2l_power = pd.read_csv('/content/drive/My Drive/CS6140_Project/lunges_2_left/AB01_lunges_2_left_power.csv');
LU2l_velocity = pd.read_csv('/content/drive/My Drive/CS6140_Project/lunges_2_left/AB01_lunges_2_left_velocity.csv');

LU2r_af = pd.read_csv('/content/drive/My Drive/CS6140_Project/lunges_2_right/AB01_lunges_2_right_activity_flag.csv');
LU2r_angle = pd.read_csv('/content/drive/My Drive/CS6140_Project/lunges_2_right/AB01_lunges_2_right_angle.csv');
LU2r_emg = pd.read_csv('/content/drive/My Drive/CS6140_Project/lunges_2_right/AB01_lunges_2_right_emg.csv');
LU2r_grf = pd.read_csv('/content/drive/My Drive/CS6140_Project/lunges_2_right/AB01_lunges_2_right_grf.csv');
LU2r_imu_real = pd.read_csv('/content/drive/My Drive/CS6140_Project/lunges_2_right/AB01_lunges_2_right_imu_real.csv');
LU2r_imu_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/lunges_2_right/AB01_lunges_2_right_imu_sim.csv');
LU2r_insole_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/lunges_2_right/AB01_lunges_2_right_insole_sim.csv');
LU2r_moment = pd.read_csv('/content/drive/My Drive/CS6140_Project/lunges_2_right/AB01_lunges_2_right_moment.csv');
LU2r_power = pd.read_csv('/content/drive/My Drive/CS6140_Project/lunges_2_right/AB01_lunges_2_right_power.csv');
LU2r_velocity = pd.read_csv('/content/drive/My Drive/CS6140_Project/lunges_2_right/AB01_lunges_2_right_velocity.csv');

ME_af = pd.read_csv('/content/drive/My Drive/CS6140_Project/meander_1/AB01_meander_1_activity_flag.csv');
ME_angle = pd.read_csv('/content/drive/My Drive/CS6140_Project/meander_1/AB01_meander_1_angle.csv');
ME_emg = pd.read_csv('/content/drive/My Drive/CS6140_Project/meander_1/AB01_meander_1_emg.csv');
ME_grf = pd.read_csv('/content/drive/My Drive/CS6140_Project/meander_1/AB01_meander_1_grf.csv');
ME_imu_real = pd.read_csv('/content/drive/My Drive/CS6140_Project/meander_1/AB01_meander_1_imu_real.csv');
ME_imu_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/meander_1/AB01_meander_1_imu_sim.csv');
ME_insole_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/meander_1/AB01_meander_1_insole_sim.csv');
ME_moment = pd.read_csv('/content/drive/My Drive/CS6140_Project/meander_1/AB01_meander_1_moment.csv');
ME_power = pd.read_csv('/content/drive/My Drive/CS6140_Project/meander_1/AB01_meander_1_power.csv');
ME_velocity = pd.read_csv('/content/drive/My Drive/CS6140_Project/meander_1/AB01_meander_1_velocity.csv');

STSsn_af = pd.read_csv('/content/drive/My Drive/CS6140_Project/sit_to_stand_1_short-noarm/AB01_sit_to_stand_1_short-noarm_activity_flag.csv');
STSsn_angle = pd.read_csv('/content/drive/My Drive/CS6140_Project/sit_to_stand_1_short-noarm/AB01_sit_to_stand_1_short-noarm_angle.csv');
STSsn_emg = pd.read_csv('/content/drive/My Drive/CS6140_Project/sit_to_stand_1_short-noarm/AB01_sit_to_stand_1_short-noarm_emg.csv');
STSsn_grf = pd.read_csv('/content/drive/My Drive/CS6140_Project/sit_to_stand_1_short-noarm/AB01_sit_to_stand_1_short-noarm_grf.csv');
STSsn_imu_real = pd.read_csv('/content/drive/My Drive/CS6140_Project/sit_to_stand_1_short-noarm/AB01_sit_to_stand_1_short-noarm_imu_real.csv');
STSsn_imu_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/sit_to_stand_1_short-noarm/AB01_sit_to_stand_1_short-noarm_imu_sim.csv');
STSsn_insole_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/sit_to_stand_1_short-noarm/AB01_sit_to_stand_1_short-noarm_insole_sim.csv');
STSsn_moment = pd.read_csv('/content/drive/My Drive/CS6140_Project/sit_to_stand_1_short-noarm/AB01_sit_to_stand_1_short-noarm_moment.csv');
STSsn_power = pd.read_csv('/content/drive/My Drive/CS6140_Project/sit_to_stand_1_short-noarm/AB01_sit_to_stand_1_short-noarm_power.csv');
STSsn_velocity = pd.read_csv('/content/drive/My Drive/CS6140_Project/sit_to_stand_1_short-noarm/AB01_sit_to_stand_1_short-noarm_velocity.csv');

STSsa_af = pd.read_csv('/content/drive/My Drive/CS6140_Project/sit_to_stand_1_short-arm/AB01_sit_to_stand_1_short-arm_activity_flag.csv');
STSsa_angle = pd.read_csv('/content/drive/My Drive/CS6140_Project/sit_to_stand_1_short-arm/AB01_sit_to_stand_1_short-arm_angle.csv');
STSsa_emg = pd.read_csv('/content/drive/My Drive/CS6140_Project/sit_to_stand_1_short-arm/AB01_sit_to_stand_1_short-arm_emg.csv');
STSsa_grf = pd.read_csv('/content/drive/My Drive/CS6140_Project/sit_to_stand_1_short-arm/AB01_sit_to_stand_1_short-arm_grf.csv');
STSsa_imu_real = pd.read_csv('/content/drive/My Drive/CS6140_Project/sit_to_stand_1_short-arm/AB01_sit_to_stand_1_short-arm_imu_real.csv');
STSsa_imu_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/sit_to_stand_1_short-arm/AB01_sit_to_stand_1_short-arm_imu_sim.csv');
STSsa_insole_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/sit_to_stand_1_short-arm/AB01_sit_to_stand_1_short-arm_insole_sim.csv');
STSsa_moment = pd.read_csv('/content/drive/My Drive/CS6140_Project/sit_to_stand_1_short-arm/AB01_sit_to_stand_1_short-arm_moment.csv');
STSsa_power = pd.read_csv('/content/drive/My Drive/CS6140_Project/sit_to_stand_1_short-arm/AB01_sit_to_stand_1_short-arm_power.csv');
STSsa_velocity = pd.read_csv('/content/drive/My Drive/CS6140_Project/sit_to_stand_1_short-arm/AB01_sit_to_stand_1_short-arm_velocity.csv');

PO_af = pd.read_csv('/content/drive/My Drive/CS6140_Project/poses_1/AB01_poses_1_activity_flag.csv');
PO_angle = pd.read_csv('/content/drive/My Drive/CS6140_Project/poses_1/AB01_poses_1_angle.csv');
PO_emg = pd.read_csv('/content/drive/My Drive/CS6140_Project/poses_1/AB01_poses_1_emg.csv');
PO_grf = pd.read_csv('/content/drive/My Drive/CS6140_Project/poses_1/AB01_poses_1_grf.csv');
PO_imu_real = pd.read_csv('/content/drive/My Drive/CS6140_Project/poses_1/AB01_poses_1_imu_real.csv');
PO_imu_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/poses_1/AB01_poses_1_imu_sim.csv');
PO_insole_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/poses_1/AB01_poses_1_insole_sim.csv');
PO_moment = pd.read_csv('/content/drive/My Drive/CS6140_Project/poses_1/AB01_poses_1_moment.csv');
PO_power = pd.read_csv('/content/drive/My Drive/CS6140_Project/poses_1/AB01_poses_1_power.csv');
PO_velocity = pd.read_csv('/content/drive/My Drive/CS6140_Project/poses_1/AB01_poses_1_velocity.csv');

PU_af = pd.read_csv('/content/drive/My Drive/CS6140_Project/push_1/AB01_push_1_activity_flag.csv');
PU_angle = pd.read_csv('/content/drive/My Drive/CS6140_Project/push_1/AB01_push_1_angle.csv');
PU_emg = pd.read_csv('/content/drive/My Drive/CS6140_Project/push_1/AB01_push_1_emg.csv');
PU_grf = pd.read_csv('/content/drive/My Drive/CS6140_Project/push_1/AB01_push_1_grf.csv');
PU_imu_real = pd.read_csv('/content/drive/My Drive/CS6140_Project/push_1/AB01_push_1_imu_real.csv');
PU_imu_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/push_1/AB01_push_1_imu_sim.csv');
PU_insole_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/push_1/AB01_push_1_insole_sim.csv');
PU_moment = pd.read_csv('/content/drive/My Drive/CS6140_Project/push_1/AB01_push_1_moment.csv');
PU_power = pd.read_csv('/content/drive/My Drive/CS6140_Project/push_1/AB01_push_1_power.csv');
PU_velocity = pd.read_csv('/content/drive/My Drive/CS6140_Project/push_1/AB01_push_1_velocity.csv');

STE2l_af = pd.read_csv('/content/drive/My Drive/CS6140_Project/step_ups_2_left/AB01_step_ups_2_left_activity_flag.csv');
STE2l_angle = pd.read_csv('/content/drive/My Drive/CS6140_Project/step_ups_2_left/AB01_step_ups_2_left_angle.csv');
STE2l_emg = pd.read_csv('/content/drive/My Drive/CS6140_Project/step_ups_2_left/AB01_step_ups_2_left_emg.csv');
STE2l_grf = pd.read_csv('/content/drive/My Drive/CS6140_Project/step_ups_2_left/AB01_step_ups_2_left_grf.csv');
STE2l_imu_real = pd.read_csv('/content/drive/My Drive/CS6140_Project/step_ups_2_left/AB01_step_ups_2_left_imu_real.csv');
STE2l_imu_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/step_ups_2_left/AB01_step_ups_2_left_imu_sim.csv');
STE2l_insole_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/step_ups_2_left/AB01_step_ups_2_left_insole_sim.csv');
STE2l_moment = pd.read_csv('/content/drive/My Drive/CS6140_Project/step_ups_2_left/AB01_step_ups_2_left_moment.csv');
STE2l_power = pd.read_csv('/content/drive/My Drive/CS6140_Project/step_ups_2_left/AB01_step_ups_2_left_power.csv');
STE2l_velocity = pd.read_csv('/content/drive/My Drive/CS6140_Project/step_ups_2_left/AB01_step_ups_2_left_velocity.csv');

STE2r_af = pd.read_csv('/content/drive/My Drive/CS6140_Project/step_ups_2_right/AB01_step_ups_2_right_activity_flag.csv');
STE2r_angle = pd.read_csv('/content/drive/My Drive/CS6140_Project/step_ups_2_right/AB01_step_ups_2_right_angle.csv');
STE2r_emg = pd.read_csv('/content/drive/My Drive/CS6140_Project/step_ups_2_right/AB01_step_ups_2_right_emg.csv');
STE2r_grf = pd.read_csv('/content/drive/My Drive/CS6140_Project/step_ups_2_right/AB01_step_ups_2_right_grf.csv');
STE2r_imu_real = pd.read_csv('/content/drive/My Drive/CS6140_Project/step_ups_2_right/AB01_step_ups_2_right_imu_real.csv');
STE2r_imu_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/step_ups_2_right/AB01_step_ups_2_right_imu_sim.csv');
STE2r_insole_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/step_ups_2_right/AB01_step_ups_2_right_insole_sim.csv');
STE2r_moment = pd.read_csv('/content/drive/My Drive/CS6140_Project/step_ups_2_right/AB01_step_ups_2_right_moment.csv');
STE2r_power = pd.read_csv('/content/drive/My Drive/CS6140_Project/step_ups_2_right/AB01_step_ups_2_right_power.csv');
STE2r_velocity = pd.read_csv('/content/drive/My Drive/CS6140_Project/step_ups_2_right/AB01_step_ups_2_right_velocity.csv');

STStn_af = pd.read_csv('/content/drive/My Drive/CS6140_Project/sit_to_stand_2_tall-noarm/AB01_sit_to_stand_2_tall-noarm_activity_flag.csv');
STStn_angle = pd.read_csv('/content/drive/My Drive/CS6140_Project/sit_to_stand_2_tall-noarm/AB01_sit_to_stand_2_tall-noarm_angle.csv');
STStn_emg = pd.read_csv('/content/drive/My Drive/CS6140_Project/sit_to_stand_2_tall-noarm/AB01_sit_to_stand_2_tall-noarm_emg.csv');
STStn_grf = pd.read_csv('/content/drive/My Drive/CS6140_Project/sit_to_stand_2_tall-noarm/AB01_sit_to_stand_2_tall-noarm_grf.csv');
STStn_imu_real = pd.read_csv('/content/drive/My Drive/CS6140_Project/sit_to_stand_2_tall-noarm/AB01_sit_to_stand_2_tall-noarm_imu_real.csv');
STStn_imu_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/sit_to_stand_2_tall-noarm/AB01_sit_to_stand_2_tall-noarm_imu_sim.csv');
STStn_insole_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/sit_to_stand_2_tall-noarm/AB01_sit_to_stand_2_tall-noarm_insole_sim.csv');
STStn_moment = pd.read_csv('/content/drive/My Drive/CS6140_Project/sit_to_stand_2_tall-noarm/AB01_sit_to_stand_2_tall-noarm_moment.csv');
STStn_power = pd.read_csv('/content/drive/My Drive/CS6140_Project/sit_to_stand_2_tall-noarm/AB01_sit_to_stand_2_tall-noarm_power.csv');
STStn_velocity = pd.read_csv('/content/drive/My Drive/CS6140_Project/sit_to_stand_2_tall-noarm/AB01_sit_to_stand_2_tall-noarm_velocity.csv');

TR_af = pd.read_csv('/content/drive/My Drive/CS6140_Project/tire_run_1/AB01_tire_run_1_activity_flag.csv');
TR_angle = pd.read_csv('/content/drive/My Drive/CS6140_Project/tire_run_1/AB01_tire_run_1_angle.csv');
TR_emg = pd.read_csv('/content/drive/My Drive/CS6140_Project/tire_run_1/AB01_tire_run_1_emg.csv');
TR_grf = pd.read_csv('/content/drive/My Drive/CS6140_Project/tire_run_1/AB01_tire_run_1_grf.csv');
TR_imu_real = pd.read_csv('/content/drive/My Drive/CS6140_Project/tire_run_1/AB01_tire_run_1_imu_real.csv');
TR_imu_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/tire_run_1/AB01_tire_run_1_imu_sim.csv');
TR_insole_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/tire_run_1/AB01_tire_run_1_insole_sim.csv');
TR_moment = pd.read_csv('/content/drive/My Drive/CS6140_Project/tire_run_1/AB01_tire_run_1_moment.csv');
TR_power = pd.read_csv('/content/drive/My Drive/CS6140_Project/tire_run_1/AB01_tire_run_1_power.csv');
TR_velocity = pd.read_csv('/content/drive/My Drive/CS6140_Project/tire_run_1/AB01_tire_run_1_velocity.csv');

TOW_af = pd.read_csv('/content/drive/My Drive/CS6140_Project/tug_of_war_1/AB01_tug_of_war_1_activity_flag.csv');
TOW_angle = pd.read_csv('/content/drive/My Drive/CS6140_Project/tug_of_war_1/AB01_tug_of_war_1_angle.csv');
TOW_emg = pd.read_csv('/content/drive/My Drive/CS6140_Project/tug_of_war_1/AB01_tug_of_war_1_emg.csv');
TOW_grf = pd.read_csv('/content/drive/My Drive/CS6140_Project/tug_of_war_1/AB01_tug_of_war_1_grf.csv');
TOW_imu_real = pd.read_csv('/content/drive/My Drive/CS6140_Project/tug_of_war_1/AB01_tug_of_war_1_imu_real.csv');
TOW_imu_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/tug_of_war_1/AB01_tug_of_war_1_imu_sim.csv');
TOW_insole_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/tug_of_war_1/AB01_tug_of_war_1_insole_sim.csv');
TOW_moment = pd.read_csv('/content/drive/My Drive/CS6140_Project/tug_of_war_1/AB01_tug_of_war_1_moment.csv');
TOW_power = pd.read_csv('/content/drive/My Drive/CS6140_Project/tug_of_war_1/AB01_tug_of_war_1_power.csv');
TOW_velocity = pd.read_csv('/content/drive/My Drive/CS6140_Project/tug_of_war_1/AB01_tug_of_war_1_velocity.csv');

TUlt_af = pd.read_csv('/content/drive/My Drive/CS6140_Project/turn_and_step_1_left-turn/AB01_turn_and_step_1_left-turn_activity_flag.csv');
TUlt_angle = pd.read_csv('/content/drive/My Drive/CS6140_Project/turn_and_step_1_left-turn/AB01_turn_and_step_1_left-turn_angle.csv');
TUlt_emg = pd.read_csv('/content/drive/My Drive/CS6140_Project/turn_and_step_1_left-turn/AB01_turn_and_step_1_left-turn_emg.csv');
TUlt_grf = pd.read_csv('/content/drive/My Drive/CS6140_Project/turn_and_step_1_left-turn/AB01_turn_and_step_1_left-turn_grf.csv');
TUlt_imu_real = pd.read_csv('/content/drive/My Drive/CS6140_Project/turn_and_step_1_left-turn/AB01_turn_and_step_1_left-turn_imu_real.csv');
TUlt_imu_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/turn_and_step_1_left-turn/AB01_turn_and_step_1_left-turn_imu_sim.csv');
TUlt_insole_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/turn_and_step_1_left-turn/AB01_turn_and_step_1_left-turn_insole_sim.csv');
TUlt_moment = pd.read_csv('/content/drive/My Drive/CS6140_Project/turn_and_step_1_left-turn/AB01_turn_and_step_1_left-turn_moment.csv');
TUlt_power = pd.read_csv('/content/drive/My Drive/CS6140_Project/turn_and_step_1_left-turn/AB01_turn_and_step_1_left-turn_power.csv');
TUlt_velocity = pd.read_csv('/content/drive/My Drive/CS6140_Project/turn_and_step_1_left-turn/AB01_turn_and_step_1_left-turn_velocity.csv');

TUrt_af = pd.read_csv('/content/drive/My Drive/CS6140_Project/turn_and_step_1_right-turn/AB01_turn_and_step_1_right-turn_activity_flag.csv');
TUrt_angle = pd.read_csv('/content/drive/My Drive/CS6140_Project/turn_and_step_1_right-turn/AB01_turn_and_step_1_right-turn_angle.csv');
TUrt_emg = pd.read_csv('/content/drive/My Drive/CS6140_Project/turn_and_step_1_right-turn/AB01_turn_and_step_1_right-turn_emg.csv');
TUrt_grf = pd.read_csv('/content/drive/My Drive/CS6140_Project/turn_and_step_1_right-turn/AB01_turn_and_step_1_right-turn_grf.csv');
TUrt_imu_real = pd.read_csv('/content/drive/My Drive/CS6140_Project/turn_and_step_1_right-turn/AB01_turn_and_step_1_right-turn_imu_real.csv');
TUrt_imu_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/turn_and_step_1_right-turn/AB01_turn_and_step_1_right-turn_imu_sim.csv');
TUrt_insole_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/turn_and_step_1_right-turn/AB01_turn_and_step_1_right-turn_insole_sim.csv');
TUrt_moment = pd.read_csv('/content/drive/My Drive/CS6140_Project/turn_and_step_1_right-turn/AB01_turn_and_step_1_right-turn_moment.csv');
TUrt_power = pd.read_csv('/content/drive/My Drive/CS6140_Project/turn_and_step_1_right-turn/AB01_turn_and_step_1_right-turn_power.csv');
TUrt_velocity = pd.read_csv('/content/drive/My Drive/CS6140_Project/turn_and_step_1_right-turn/AB01_turn_and_step_1_right-turn_velocity.csv');

TW_af = pd.read_csv('/content/drive/My Drive/CS6140_Project/twister_1/AB01_twister_1_activity_flag.csv');
TW_angle = pd.read_csv('/content/drive/My Drive/CS6140_Project/twister_1/AB01_twister_1_angle.csv');
TW_emg = pd.read_csv('/content/drive/My Drive/CS6140_Project/twister_1/AB01_twister_1_emg.csv');
TW_grf = pd.read_csv('/content/drive/My Drive/CS6140_Project/twister_1/AB01_twister_1_grf.csv');
TW_imu_real = pd.read_csv('/content/drive/My Drive/CS6140_Project/twister_1/AB01_twister_1_imu_real.csv');
TW_imu_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/twister_1/AB01_twister_1_imu_sim.csv');
TW_insole_sim = pd.read_csv('/content/drive/My Drive/CS6140_Project/twister_1/AB01_twister_1_insole_sim.csv');
TW_moment = pd.read_csv('/content/drive/My Drive/CS6140_Project/twister_1/AB01_twister_1_moment.csv');
TW_power = pd.read_csv('/content/drive/My Drive/CS6140_Project/twister_1/AB01_twister_1_power.csv');
TW_velocity = pd.read_csv('/content/drive/My Drive/CS6140_Project/twister_1/AB01_twister_1_velocity.csv');

# %% [markdown]
# # Data Assignment

# %%
# Cyclic data:
dfs = [WDbk_angle,WDbk_imu_real,WDbk_velocity]
merge = partial(pd.merge, on = 'time', how = 'inner')
WDbk = reduce(merge,dfs)
WDbk['Class'] = np.ones(len(WDbk))
WDbk.loc[:,'time'] = WDbk['time'].apply(lambda x: x - WDbk.loc[0][0])

dfs = [WDhw_angle,WDhw_imu_real,WDhw_velocity]
merge = partial(pd.merge, on = 'time', how = 'inner')
WDhw = reduce(merge,dfs)
WDhw['Class'] = np.ones(len(WDhw))
WDhw.loc[:,'time'] = WDhw['time'].apply(lambda x: x - WDhw.loc[0][0])

dfs = [WDhk_angle,WDhk_imu_real,WDhk_velocity]
merge = partial(pd.merge, on = 'time', how = 'inner')
WDhk = reduce(merge,dfs)
WDhk['Class'] = np.ones(len(WDhk))
WDhk.loc[:,'time'] = WDhk['time'].apply(lambda x: x - WDhk.loc[0][0])

dfs = [WDtw_angle,WDtw_imu_real,WDtw_velocity]
merge = partial(pd.merge, on = 'time', how = 'inner')
WDtw = reduce(merge,dfs)
WDtw['Class'] = np.ones(len(WDtw))
WDtw.loc[:,'time'] = WDtw['time'].apply(lambda x: x - WDtw.loc[0][0])

dfs = [WId5_angle,WId5_imu_real,WId5_velocity]
merge = partial(pd.merge, on = 'time', how = 'inner')
WId5 = reduce(merge,dfs)
WId5['Class'] = np.ones(len(WId5))
WId5.loc[:,'time'] = WId5['time'].apply(lambda x: x - WId5.loc[0][0])

dfs = [WIu5_angle,WIu5_imu_real,WIu5_velocity]
merge = partial(pd.merge, on = 'time', how = 'inner')
WIu5 = reduce(merge,dfs)
WIu5['Class'] = np.ones(len(WIu5))
WIu5.loc[:,'time'] = WIu5['time'].apply(lambda x: x - WIu5.loc[0][0])

dfs = [WId10_angle,WId10_imu_real,WId10_velocity]
merge = partial(pd.merge, on = 'time', how = 'inner')
WId10 = reduce(merge,dfs)
WId10['Class'] = np.ones(len(WId10))
WId10.loc[:,'time'] = WId10['time'].apply(lambda x: x - WId10.loc[0][0])

dfs = [WIu10_angle,WIu10_imu_real,WIu10_velocity]
merge = partial(pd.merge, on = 'time', how = 'inner')
WIu10 = reduce(merge,dfs)
WIu10['Class'] = np.ones(len(WIu10))
WIu10.loc[:,'time'] = WIu10['time'].apply(lambda x: x - WIu10.loc[0][0])

dfs = [WN06_angle,WN06_imu_real,WN06_velocity]
merge = partial(pd.merge, on = 'time', how = 'inner')
WN06 = reduce(merge,dfs)
WN06['Class'] = np.ones(len(WN06))
WN06.loc[:,'time'] = WN06['time'].apply(lambda x: x - WN06.loc[0][0])

dfs = [WN12_angle,WN12_imu_real,WN12_velocity]
merge = partial(pd.merge, on = 'time', how = 'inner')
WN12 = reduce(merge,dfs)
WN12['Class'] = np.ones(len(WN12))
WN12.loc[:,'time'] = WN12['time'].apply(lambda x: x - WN12.loc[0][0])

dfs = [WN18_angle,WN18_imu_real,WN18_velocity]
merge = partial(pd.merge, on = 'time', how = 'inner')
WN18 = reduce(merge,dfs)
WN18['Class'] = np.ones(len(WN18))
WN18.loc[:,'time'] = WN18['time'].apply(lambda x: x - WN18.loc[0][0])

dfs = [WN20_angle,WN20_imu_real,WN20_velocity]
merge = partial(pd.merge, on = 'time', how = 'inner')
WN20 = reduce(merge,dfs)
WN20['Class'] = np.ones(len(WN20))
WN20.loc[:,'time'] = WN20['time'].apply(lambda x: x - WN20.loc[0][0])

dfs = [WN25_angle,WN25_imu_real,WN25_velocity]
merge = partial(pd.merge, on = 'time', how = 'inner')
WN25 = reduce(merge,dfs)
WN25['Class'] = np.ones(len(WN25))
WN25.loc[:,'time'] = WN25['time'].apply(lambda x: x - WN25.loc[0][0])

dfs = [WNsh_angle,WNsh_imu_real,WNsh_velocity]
merge = partial(pd.merge, on = 'time', how = 'inner')
WNsh = reduce(merge,dfs)
WNsh['Class'] = np.ones(len(WNsh))
WNsh.loc[:,'time'] = WNsh['time'].apply(lambda x: x - WNsh.loc[0][0])

dfs = [WNsk_angle,WNsk_imu_real,WNsk_velocity]
merge = partial(pd.merge, on = 'time', how = 'inner')
WNsk = reduce(merge,dfs)
WNsk['Class'] = np.ones(len(WNsk))
WNsk.loc[:,'time'] = WNsk['time'].apply(lambda x: x - WNsk.loc[0][0])

dfs = [WO_angle,WO_imu_real,WO_velocity]
merge = partial(pd.merge, on = 'time', how = 'inner')
WO = reduce(merge,dfs)
WO['Class'] = np.ones(len(WO))
WO.loc[:,'time'] = WO['time'].apply(lambda x: x - WO.loc[0][0])

dfs = [SS_angle,SS_imu_real,SS_velocity]
merge = partial(pd.merge, on = 'time', how = 'inner')
SS = reduce(merge,dfs)
SS['Class'] = np.ones(len(SS))
SS.loc[:,'time'] = SS['time'].apply(lambda x: x - SS.loc[0][0])

dfs = [SQ0_angle,SQ0_imu_real,SQ0_velocity]
merge = partial(pd.merge, on = 'time', how = 'inner')
SQ0 = reduce(merge,dfs)
SQ0['Class'] = np.ones(len(SQ0))
SQ0.loc[:,'time'] = SQ0['time'].apply(lambda x: x - SQ0.loc[0][0])

dfs = [SQ25_angle,SQ25_imu_real,SQ25_velocity]
merge = partial(pd.merge, on = 'time', how = 'inner')
SQ25 = reduce(merge,dfs)
SQ25['Class'] = np.ones(len(SQ25))
SQ25.loc[:,'time'] = SQ25['time'].apply(lambda x: x - SQ25.loc[0][0])

dfs = [STA1u_angle,STA1u_imu_real,STA1u_velocity]
merge = partial(pd.merge, on = 'time', how = 'inner')
STA1u = reduce(merge,dfs)
STA1u['Class'] = np.ones(len(STA1u))
STA1u.loc[:,'time'] = STA1u['time'].apply(lambda x: x - STA1u.loc[0][0])

dfs = [STA2d_angle,STA2d_imu_real,STA2d_velocity]
merge = partial(pd.merge, on = 'time', how = 'inner')
STA2d = reduce(merge,dfs)
STA2d['Class'] = np.ones(len(STA2d))
STA2d.loc[:,'time'] = STA2d['time'].apply(lambda x: x - STA2d.loc[0][0])

dfs = [STA3u_angle,STA3u_imu_real,STA3u_velocity]
merge = partial(pd.merge, on = 'time', how = 'inner')
STA3u = reduce(merge,dfs)
STA3u['Class'] = np.ones(len(STA3u))
STA3u.loc[:,'time'] = STA3u['time'].apply(lambda x: x - STA3u.loc[0][0])

dfs = [STA4d_angle,STA4d_imu_real,STA4d_velocity]
merge = partial(pd.merge, on = 'time', how = 'inner')
STA4d = reduce(merge,dfs)
STA4d['Class'] = np.ones(len(STA4d))
STA4d.loc[:,'time'] = STA4d['time'].apply(lambda x: x - STA4d.loc[0][0])

dfs = [STA5u_angle,STA5u_imu_real,STA5u_velocity]
merge = partial(pd.merge, on = 'time', how = 'inner')
STA5u = reduce(merge,dfs)
STA5u['Class'] = np.ones(len(STA5u))
STA5u.loc[:,'time'] = STA5u['time'].apply(lambda x: x - STA5u.loc[0][0])

dfs = [STA6d_angle,STA6d_imu_real,STA6d_velocity]
merge = partial(pd.merge, on = 'time', how = 'inner')
STA6d = reduce(merge,dfs)
STA6d['Class'] = np.ones(len(STA6d))
STA6d.loc[:,'time'] = STA6d['time'].apply(lambda x: x - STA6d.loc[0][0])

dfs = [STA7u_angle,STA7u_imu_real,STA7u_velocity]
merge = partial(pd.merge, on = 'time', how = 'inner')
STA7u = reduce(merge,dfs)
STA7u['Class'] = np.ones(len(STA7u))
STA7u.loc[:,'time'] = STA7u['time'].apply(lambda x: x - STA7u.loc[0][0])

dfs = [STA8d_angle,STA8d_imu_real,STA8d_velocity]
merge = partial(pd.merge, on = 'time', how = 'inner')
STA8d = reduce(merge,dfs)
STA8d['Class'] = np.ones(len(STA8d))
STA8d.loc[:,'time'] = STA8d['time'].apply(lambda x: x - STA8d.loc[0][0])

dfs = [STA9u_angle,STA9u_imu_real,STA9u_velocity]
merge = partial(pd.merge, on = 'time', how = 'inner')
STA9u = reduce(merge,dfs)
STA9u['Class'] = np.ones(len(STA9u))
STA9u.loc[:,'time'] = STA9u['time'].apply(lambda x: x - STA9u.loc[0][0])

dfs = [STA10d_angle,STA10d_imu_real,STA10d_velocity]
merge = partial(pd.merge, on = 'time', how = 'inner')
STA10d = reduce(merge,dfs)
STA10d['Class'] = np.ones(len(STA10d))
STA10d.loc[:,'time'] = STA10d['time'].apply(lambda x: x - STA10d.loc[0][0])

dfs = [WB06_angle,WB06_imu_real,WB06_velocity]
merge = partial(pd.merge, on = 'time', how = 'inner')
WB06 = reduce(merge,dfs)
WB06['Class'] = np.ones(len(WB06))
WB06.loc[:,'time'] = WB06['time'].apply(lambda x: x - WB06.loc[0][0])

dfs = [WB08_angle,WB08_imu_real,WB08_velocity]
merge = partial(pd.merge, on = 'time', how = 'inner')
WB08 = reduce(merge,dfs)
WB08['Class'] = np.ones(len(WB08))
WB08.loc[:,'time'] = WB08['time'].apply(lambda x: x - WB08.loc[0][0])

dfs = [WB10_angle,WB10_imu_real,WB10_velocity]
merge = partial(pd.merge, on = 'time', how = 'inner')
WB10 = reduce(merge,dfs)
WB10['Class'] = np.ones(len(WB10))
WB10.loc[:,'time'] = WB10['time'].apply(lambda x: x - WB10.loc[0][0])

dfs = [WW25_angle,WW25_imu_real,WW25_velocity]
merge = partial(pd.merge, on = 'time', how = 'inner')
WW25 = reduce(merge,dfs)
WW25['Class'] = np.ones(len(WW25))
WW25.loc[:,'time'] = WW25['time'].apply(lambda x: x - WW25.loc[0][0])
WW25.head()




# Non-cyclic data

dfs = [BTc_angle,BTc_imu_real,BTc_velocity]
merge = partial(pd.merge, on = 'time', how = 'inner')
BTc = reduce(merge,dfs)
BTc['Class'] = np.zeros(len(BTc))
BTc.loc[:,'time'] = BTc['time'].apply(lambda x: x - BTc.loc[0][0])

dfs = [BTl_angle,BTl_imu_real,BTl_velocity]
merge = partial(pd.merge, on = 'time', how = 'inner')
BTl = reduce(merge,dfs)
BTl['Class'] = np.zeros(len(BTl))
BTl.loc[:,'time'] = BTl['time'].apply(lambda x: x - BTl.loc[0][0])

dfs = [BTr_angle,BTr_imu_real,BTr_velocity]
merge = partial(pd.merge, on = 'time', how = 'inner')
BTr = reduce(merge,dfs)
BTr['Class'] = np.zeros(len(BTr))
BTr.loc[:,'time'] = BTr['time'].apply(lambda x: x - BTr.loc[0][0])

dfs = [CURd_angle,CURd_imu_real,CURd_velocity]
merge = partial(pd.merge, on = 'time', how = 'inner')
CURd = reduce(merge,dfs)
CURd['Class'] = np.zeros(len(CURd))
CURd.loc[:,'time'] = CURd['time'].apply(lambda x: x - CURd.loc[0][0])

dfs = [CURu_angle,CURu_imu_real,CURu_velocity]
merge = partial(pd.merge, on = 'time', how = 'inner')
CURu = reduce(merge,dfs)
CURu['Class'] = np.zeros(len(CURu))
CURu.loc[:,'time'] = CURu['time'].apply(lambda x: x - CURu.loc[0][0])

dfs = [CUTlf_angle,CUTlf_imu_real,CUTlf_velocity]
merge = partial(pd.merge, on = 'time', how = 'inner')
CUTlf = reduce(merge,dfs)
CUTlf['Class'] = np.zeros(len(CUTlf))
CUTlf.loc[:,'time'] = CUTlf['time'].apply(lambda x: x - CUTlf.loc[0][0])

dfs = [CUTls_angle,CUTls_imu_real,CUTls_velocity]
merge = partial(pd.merge, on = 'time', how = 'inner')
CUTls = reduce(merge,dfs)
CUTls['Class'] = np.zeros(len(CUTls))
CUTls.loc[:,'time'] = CUTls['time'].apply(lambda x: x - CUTls.loc[0][0])

dfs = [CUTrf_angle,CUTrf_imu_real,CUTrf_velocity]
merge = partial(pd.merge, on = 'time', how = 'inner')
CUTrf = reduce(merge,dfs)
CUTrf['Class'] = np.zeros(len(CUTrf))
CUTrf.loc[:,'time'] = CUTrf['time'].apply(lambda x: x - CUTrf.loc[0][0])

dfs = [CUTrs_angle,CUTrs_imu_real,CUTrs_velocity]
merge = partial(pd.merge, on = 'time', how = 'inner')
CUTrs = reduce(merge,dfs)
CUTrs['Class'] = np.zeros(len(CUTrs))
CUTrs.loc[:,'time'] = CUTrs['time'].apply(lambda x: x - CUTrs.loc[0][0])

dfs = [JUfb_angle,JUfb_imu_real,JUfb_velocity]
merge = partial(pd.merge, on = 'time', how = 'inner')
JUfb = reduce(merge,dfs)
JUfb['Class'] = np.zeros(len(JUfb))
JUfb.loc[:,'time'] = JUfb['time'].apply(lambda x: x - JUfb.loc[0][0])

dfs = [JUh_angle,JUh_imu_real,JUh_velocity]
merge = partial(pd.merge, on = 'time', how = 'inner')
JUh = reduce(merge,dfs)
JUh['Class'] = np.zeros(len(JUh))
JUh.loc[:,'time'] = JUh['time'].apply(lambda x: x - JUh.loc[0][0])

dfs = [JUfv_angle,JUfv_imu_real,JUfv_velocity]
merge = partial(pd.merge, on = 'time', how = 'inner')
JUfv = reduce(merge,dfs)
JUfv['Class'] = np.zeros(len(JUfv))
JUfv.loc[:,'time'] = JUfv['time'].apply(lambda x: x - JUfv.loc[0][0])

dfs = [JU901_angle,JU901_imu_real,JU901_velocity]
merge = partial(pd.merge, on = 'time', how = 'inner')
JU901 = reduce(merge,dfs)
JU901['Class'] = np.zeros(len(JU901))
JU901.loc[:,'time'] = JU901['time'].apply(lambda x: x - JU901.loc[0][0])

dfs = [JU902_angle,JU902_imu_real,JU902_velocity]
merge = partial(pd.merge, on = 'time', how = 'inner')
JU902 = reduce(merge,dfs)
JU902['Class'] = np.zeros(len(JU902))
JU902.loc[:,'time'] = JU902['time'].apply(lambda x: x - JU902.loc[0][0])

dfs = [JU180_angle,JU180_imu_real,JU180_velocity]
merge = partial(pd.merge, on = 'time', how = 'inner')
JU180 = reduce(merge,dfs)
JU180['Class'] = np.zeros(len(JU180))
JU180.loc[:,'time'] = JU180['time'].apply(lambda x: x - JU180.loc[0][0])

dfs = [JUl_angle,JUl_imu_real,JUl_velocity]
merge = partial(pd.merge, on = 'time', how = 'inner')
JUl = reduce(merge,dfs)
JUl['Class'] = np.zeros(len(JUl))
JUl.loc[:,'time'] = JUl['time'].apply(lambda x: x - JUl.loc[0][0])

dfs = [LW25lc_angle,LW25lc_imu_real,LW25lc_velocity]
merge = partial(pd.merge, on = 'time', how = 'inner')
LW25lc = reduce(merge,dfs)
LW25lc['Class'] = np.zeros(len(LW25lc))
LW25lc.loc[:,'time'] = LW25lc['time'].apply(lambda x: x - LW25lc.loc[0][0])

dfs = [LW25ll_angle,LW25ll_imu_real,LW25ll_velocity]
merge = partial(pd.merge, on = 'time', how = 'inner')
LW25ll = reduce(merge,dfs)
LW25ll['Class'] = np.zeros(len(LW25ll))
LW25ll.loc[:,'time'] = LW25ll['time'].apply(lambda x: x - LW25ll.loc[0][0])

dfs = [LW25rc_angle,LW25rc_imu_real,LW25rc_velocity]
merge = partial(pd.merge, on = 'time', how = 'inner')
LW25rc = reduce(merge,dfs)
LW25rc['Class'] = np.zeros(len(LW25rc))
LW25rc.loc[:,'time'] = LW25rc['time'].apply(lambda x: x - LW25rc.loc[0][0])

dfs = [LW25rr_angle,LW25rr_imu_real,LW25rr_velocity]
merge = partial(pd.merge, on = 'time', how = 'inner')
LW25rr = reduce(merge,dfs)
LW25rr['Class'] = np.zeros(len(LW25rr))
LW25rr.loc[:,'time'] = LW25rr['time'].apply(lambda x: x - LW25rr.loc[0][0])

dfs = [LW0lc_angle,LW0lc_imu_real,LW0lc_velocity]
merge = partial(pd.merge, on = 'time', how = 'inner')
LW0lc = reduce(merge,dfs)
LW0lc['Class'] = np.zeros(len(LW0lc))
LW0lc.loc[:,'time'] = LW0lc['time'].apply(lambda x: x - LW0lc.loc[0][0])

dfs = [LW0ll_angle,LW0ll_imu_real,LW0ll_velocity]
merge = partial(pd.merge, on = 'time', how = 'inner')
LW0ll = reduce(merge,dfs)
LW0ll['Class'] = np.zeros(len(LW0ll))
LW0ll.loc[:,'time'] = LW0ll['time'].apply(lambda x: x - LW0ll.loc[0][0])

dfs = [LW0rc_angle,LW0rc_imu_real,LW0rc_velocity]
merge = partial(pd.merge, on = 'time', how = 'inner')
LW0rc = reduce(merge,dfs)
LW0rc['Class'] = np.zeros(len(LW0rc))
LW0rc.loc[:,'time'] = LW0rc['time'].apply(lambda x: x - LW0rc.loc[0][0])

dfs = [LW0rr_angle,LW0rr_imu_real,LW0rr_velocity]
merge = partial(pd.merge, on = 'time', how = 'inner')
LW0rr = reduce(merge,dfs)
LW0rr['Class'] = np.zeros(len(LW0rr))
LW0rr.loc[:,'time'] = LW0rr['time'].apply(lambda x: x - LW0rr.loc[0][0])

dfs = [LU1_angle,LU1_imu_real,LU1_velocity]
merge = partial(pd.merge, on = 'time', how = 'inner')
LU1 = reduce(merge,dfs)
LU1['Class'] = np.zeros(len(LU1))
LU1.loc[:,'time'] = LU1['time'].apply(lambda x: x - LU1.loc[0][0])

dfs = [LU2l_angle,LU2l_imu_real,LU2l_velocity]
merge = partial(pd.merge, on = 'time', how = 'inner')
LU2l = reduce(merge,dfs)
LU2l['Class'] = np.zeros(len(LU2l))
LU2l.loc[:,'time'] = LU2l['time'].apply(lambda x: x - LU2l.loc[0][0])

dfs = [LU2r_angle,LU2r_imu_real,LU2r_velocity]
merge = partial(pd.merge, on = 'time', how = 'inner')
LU2r = reduce(merge,dfs)
LU2r['Class'] = np.zeros(len(LU2r))
LU2r.loc[:,'time'] = LU2r['time'].apply(lambda x: x - LU2r.loc[0][0])

dfs = [ME_angle,ME_imu_real,ME_velocity]
merge = partial(pd.merge, on = 'time', how = 'inner')
ME = reduce(merge,dfs)
ME['Class'] = np.zeros(len(ME))
ME.loc[:,'time'] = ME['time'].apply(lambda x: x - ME.loc[0][0])

dfs = [STSsn_angle,STSsn_imu_real,STSsn_velocity]
merge = partial(pd.merge, on = 'time', how = 'inner')
STSsn = reduce(merge,dfs)
STSsn['Class'] = np.zeros(len(STSsn))
STSsn.loc[:,'time'] = STSsn['time'].apply(lambda x: x - STSsn.loc[0][0])

dfs = [STSsa_angle,STSsa_imu_real,STSsa_velocity]
merge = partial(pd.merge, on = 'time', how = 'inner')
STSsa = reduce(merge,dfs)
STSsa['Class'] = np.zeros(len(STSsa))
STSsa.loc[:,'time'] = STSsa['time'].apply(lambda x: x - STSsa.loc[0][0])

dfs = [PO_angle,PO_imu_real,PO_velocity]
merge = partial(pd.merge, on = 'time', how = 'inner')
PO = reduce(merge,dfs)
PO['Class'] = np.zeros(len(PO))
PO.loc[:,'time'] = PO['time'].apply(lambda x: x - PO.loc[0][0])

dfs = [PU_angle,PU_imu_real,PU_velocity]
merge = partial(pd.merge, on = 'time', how = 'inner')
PU = reduce(merge,dfs)
PU['Class'] = np.zeros(len(PU))
PU.loc[:,'time'] = PU['time'].apply(lambda x: x - PU.loc[0][0])

dfs = [STE2l_angle,STE2l_imu_real,STE2l_velocity]
merge = partial(pd.merge, on = 'time', how = 'inner')
STE2l = reduce(merge,dfs)
STE2l['Class'] = np.zeros(len(STE2l))
STE2l.loc[:,'time'] = STE2l['time'].apply(lambda x: x - STE2l.loc[0][0])

dfs = [STE2r_angle,STE2r_imu_real,STE2r_velocity]
merge = partial(pd.merge, on = 'time', how = 'inner')
STE2r = reduce(merge,dfs)
STE2r['Class'] = np.zeros(len(STE2r))
STE2r.loc[:,'time'] = STE2r['time'].apply(lambda x: x - STE2r.loc[0][0])

dfs = [STStn_angle,STStn_imu_real,STStn_velocity]
merge = partial(pd.merge, on = 'time', how = 'inner')
STStn = reduce(merge,dfs)
STStn['Class'] = np.zeros(len(STStn))
STStn.loc[:,'time'] = STStn['time'].apply(lambda x: x - STStn.loc[0][0])

dfs = [TR_angle,TR_imu_real,TR_velocity]
merge = partial(pd.merge, on = 'time', how = 'inner')
TR = reduce(merge,dfs)
TR['Class'] = np.zeros(len(TR))
TR.loc[:,'time'] = TR['time'].apply(lambda x: x - TR.loc[0][0])

dfs = [TOW_angle,TOW_imu_real,TOW_velocity]
merge = partial(pd.merge, on = 'time', how = 'inner')
TOW = reduce(merge,dfs)
TOW['Class'] = np.zeros(len(TOW))
TOW.loc[:,'time'] = TOW['time'].apply(lambda x: x - TOW.loc[0][0])

dfs = [TUlt_angle,TUlt_imu_real,TUlt_velocity]
merge = partial(pd.merge, on = 'time', how = 'inner')
TUlt = reduce(merge,dfs)
TUlt['Class'] = np.zeros(len(TUlt))
TUlt.loc[:,'time'] = TUlt['time'].apply(lambda x: x - TUlt.loc[0][0])

dfs = [TUrt_angle,TUrt_imu_real,TUrt_velocity]
merge = partial(pd.merge, on = 'time', how = 'inner')
TUrt = reduce(merge,dfs)
TUrt['Class'] = np.zeros(len(TUrt))
TUrt.loc[:,'time'] = TUrt['time'].apply(lambda x: x - TUrt.loc[0][0])

dfs = [TW_angle,TW_imu_real,TW_velocity]
merge = partial(pd.merge, on = 'time', how = 'inner')
TW = reduce(merge,dfs)
TW['Class'] = np.zeros(len(TW))
TW.loc[:,'time'] = TW['time'].apply(lambda x: x - TW.loc[0][0])

# %% [markdown]
# # Cyclic vs. Non-cyclic Data Assignment

# %%
# combining individual dataframes into respective cyclic or non-cyclic dataframe
cyclic_dfs = [WDbk,WDhw,WDhk,WDtw,WId5,WIu5,WId10,WIu10,WN06,WN12,WN18,WN20,WN25,WNsh,WNsk,WO,SS,SQ0,SQ25,STA1u,STA2d,STA3u,STA4d,STA5u,STA6d,STA7u,STA8d,STA9u,STA10d,WB06,WB08,WB10,WW25]
non_cyclic_dfs = [BTc,BTl,BTr,CURd,CURu,CUTlf,CUTls,CUTrf,CUTrs,JUfb,JUh,JUfv,JU901,JU902,JU180,JUl,LW25lc,LW25ll,LW25rc,LW25rr,LW0lc,LW0ll,LW0rc,LW0rr,LU1,LU2l,LU2r,ME,STSsn,STSsa,PO,PU,STE2l,STE2r,STStn,TR,TOW,TUlt,TUrt,TW]

nCyclic = len(cyclic_dfs)
nNonCyclic = len(non_cyclic_dfs)

print("number of cyclic dfs = ",nCyclic)
print("number of non-cyclic dfs = ",nNonCyclic)
# Out:
# number of cyclic dfs =  33
# number of non-cyclic dfs =  40

# %% [markdown]
# # Train and Test Dataframes Assignment

# %%
# randomly generated without replacement
train_cyclic_dfs_nums = [1,20,15,16,13,18,8,7,17,11,6,12,21,31,26,9,24,22,4,28,0,27,5,2,14]
# all numbers that aren't in train_cyclic_dfs_nums
test_cyclic_dfs_nums = [3,10,19,23,25,29,30]

# %%
# contains all training dfs, all cyclic
train_dfs = [cyclic_dfs[i] for i in train_cyclic_dfs_nums]

# %%
# contains all testing dfs, a couple of cyclic and all of non-cyclic
test_dfs_cyclic = [cyclic_dfs[i] for i in test_cyclic_dfs_nums]
test_dfs = np.concatenate((test_dfs_cyclic, non_cyclic_dfs))

# %%
print("Number of NaN values in WDbk = ", WDbk.isnull().sum().sum())
# Out:
# Number of NaN values in WDbk =  0

# %% [markdown]
# # Model: DBSCAN & One-Class SVM

# %%
import pandas as pd
import numpy as np
from functools import reduce
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import DBSCAN
from sklearn.svm import OneClassSVM
from sklearn.metrics import accuracy_score, classification_report

# implement cyclic action detection algorithm using SVM and DBSCAN
def detect_cyclic_actions(train_df, test_df):
    # Separate features and labels for training
    X_train = train_df.drop(columns=['time', 'Class'])
    y_train = train_df['Class']

    # Normalize the features
    scaler = StandardScaler()
    X_train_normalized = scaler.fit_transform(X_train)

    # Step 2: Apply DBSCAN clustering on the training data
    dbscan = DBSCAN(eps = 0.5, min_samples=5)
    train_df['cluster_label'] = dbscan.fit_predict(X_train_normalized)

    # Step 3: Train the One-Class SVM
    # Filter out the outliers (cluster label = -1)
    X_train_filtered = X_train_normalized[train_df['cluster_label'] != -1]

    # Create and train the One-Class SVM classifier
    classifier = OneClassSVM(kernel='linear', nu=0.1)
    classifier.fit(X_train_filtered)

    # Step 4: Test the classifier
    # Separate features and labels for testing
    X_test = test_df.drop(columns=['time', 'Class'])
    y_test = test_df['Class']

    # Normalize the features for testing
    X_test_normalized = scaler.transform(X_test)

    # Predict the labels using the trained One-Class SVM classifier
    predicted_labels = classifier.predict(X_test_normalized)

    # Convert predicted labels (-1 for outliers, 1 for inliers) to binary labels (0 for outliers, 1 for inliers)
    binary_labels = (predicted_labels == 1).astype(int)

    # Evaluate the classifier
    accuracy = accuracy_score(y_test, binary_labels)
    print(f"Accuracy: {accuracy:.2f}")
    print(classification_report(y_test, binary_labels))

# %% [markdown]
# ### Ablation: DBSCAN & SVM

# %%
# concatenate the cleaned dataframes back together
train_combined_df = pd.concat(train_dfs)
print(list(train_combined_df.columns))
test_combined_df = pd.concat(test_dfs)
print(list(test_combined_df.columns))

# drop hip flexion columns
train_combined_df_flexionDrop = train_combined_df.drop(columns=['hip_flexion_r', 'hip_flexion_l'])
test_combined_df_flexionDrop = test_combined_df.drop(columns=['hip_flexion_r', 'hip_flexion_l'])

# drop hip rotation columns
train_combined_df_rotationDrop = train_combined_df.drop(columns=['hip_rotation_r', 'hip_rotation_l'])
test_combined_df_rotationDrop = test_combined_df.drop(columns=['hip_rotation_r', 'hip_rotation_l'])

# drop knee angle columns
train_combined_df_kneeAngleDrop = train_combined_df.drop(columns=['knee_angle_r', 'knee_angle_l'])
test_combined_df_kneeAngleDrop = test_combined_df.drop(columns=['knee_angle_r', 'knee_angle_l'])

# drop knee velocity columns
train_combined_df_kneeVelocityDrop = train_combined_df.drop(columns=['knee_velocity_r', 'knee_velocity_l'])
test_combined_df_kneeVelocityDrop = test_combined_df.drop(columns=['knee_velocity_r', 'knee_velocity_l'])

# drop ankle angle columns
train_combined_df_ankleAngleDrop = train_combined_df.drop(columns=['ankle_angle_r', 'ankle_angle_l'])
test_combined_df_ankleAngleDrop = test_combined_df.drop(columns=['ankle_angle_r', 'ankle_angle_l'])

# apply the cyclic action detection algorithm on the combined training and testing dataframes
print("\n")
print("Original")
detect_cyclic_actions(train_combined_df, test_combined_df)
print("Dropped Hip Flexion")
detect_cyclic_actions(train_combined_df_flexionDrop, test_combined_df_flexionDrop)
print("Dropped Hip Rotation")
detect_cyclic_actions(train_combined_df_rotationDrop, test_combined_df_rotationDrop)
print("Dropped Knee Angle")
detect_cyclic_actions(train_combined_df_kneeAngleDrop, test_combined_df_kneeAngleDrop)
print("Dropped Knee Velocity")
detect_cyclic_actions(train_combined_df_kneeVelocityDrop, test_combined_df_kneeVelocityDrop)
print("Dropped Ankle Angle")
detect_cyclic_actions(train_combined_df_ankleAngleDrop, test_combined_df_ankleAngleDrop)
# Out:
# ['time', 'hip_flexion_r', 'hip_adduction_r', 'hip_rotation_r', 'knee_angle_r', 'ankle_angle_r', 'subtalar_angle_r', 'hip_flexion_l', 'hip_adduction_l', 'hip_rotation_l', 'knee_angle_l', 'ankle_angle_l', 'subtalar_angle_l', 'LShank_ACCX', 'LShank_ACCY', 'LShank_ACCZ', 'LShank_GYROX', 'LShank_GYROY', 'LShank_GYROZ', 'RShank_ACCX', 'RShank_ACCY', 'RShank_ACCZ', 'RShank_GYROX', 'RShank_GYROY', 'RShank_GYROZ', 'LAThigh_ACCX', 'LAThigh_ACCY', 'LAThigh_ACCZ', 'LAThigh_GYROX', 'LAThigh_GYROY', 'LAThigh_GYROZ', 'RAThigh_ACCX', 'RAThigh_ACCY', 'RAThigh_ACCZ', 'RAThigh_GYROX', 'RAThigh_GYROY', 'RAThigh_GYROZ', 'LPThigh_ACCX', 'LPThigh_ACCY', 'LPThigh_ACCZ', 'LPThigh_GYROX', 'LPThigh_GYROY', 'LPThigh_GYROZ', 'RPThigh_ACCX', 'RPThigh_ACCY', 'RPThigh_ACCZ', 'RPThigh_GYROX', 'RPThigh_GYROY', 'RPThigh_GYROZ', 'LPelvis_ACCX', 'LPelvis_ACCY', 'LPelvis_ACCZ', 'LPelvis_GYROX', 'LPelvis_GYROY', 'LPelvis_GYROZ', 'RPelvis_ACCX', 'RPelvis_ACCY', 'RPelvis_ACCZ', 'RPelvis_GYROX', 'RPelvis_GYROY', 'RPelvis_GYR
# ...

# %% [markdown]
# # Model: DBSCAN & SVM, Downsampling

# %%
# downsample data because human movement does not happen very much above 10 Hz
all_dfs = [WDbk,WDhw,WDhk,WDtw,WId5,WIu5,WId10,WIu10,WN06,WN12,WN18,WN20,WN25,WNsh,WNsk,WO,SS,SQ0,SQ25,STA1u,STA2d,STA3u,STA4d,STA5u,STA6d,STA7u,STA8d,STA9u,STA10d,WB06,WB08,WB10,WW25, BTc,BTl,BTr,CURd,CURu,CUTlf,CUTls,CUTrf,CUTrs,JUfb,JUh,JUfv,JU901,JU902,JU180,JUl,LW25lc,LW25ll,LW25rc,LW25rr,LW0lc,LW0ll,LW0rc,LW0rr,LU1,LU2l,LU2r,ME,STSsn,STSsa,PO,PU,STE2l,STE2r,STStn,TR,TOW,TUlt,TUrt,TW]
downsample_factor=20

# create new DataFrames with the downsampled data
WDbk_ds = WDbk[::downsample_factor]
WDhw_ds = WDhw[::downsample_factor]
WDhk_ds = WDhk[::downsample_factor]
WDtw_ds = WDtw[::downsample_factor]
WId5_ds = WId5[::downsample_factor]
WIu5_ds = WIu5[::downsample_factor]
WId10_ds = WId10[::downsample_factor]
WIu10_ds = WIu10[::downsample_factor]
WN06_ds = WN06[::downsample_factor]
WN12_ds = WN12[::downsample_factor]
WN18_ds = WN18[::downsample_factor]
WN20_ds = WN20[::downsample_factor]
WN25_ds = WN25[::downsample_factor]
WNsh_ds = WNsh[::downsample_factor]
WNsk_ds = WNsk[::downsample_factor]
WO_ds = WO[::downsample_factor]
SS_ds = SS[::downsample_factor]
SQ0_ds = SQ0[::downsample_factor]
SQ25_ds = SQ25[::downsample_factor]
STA1u_ds = STA1u[::downsample_factor]
STA2d_ds = STA2d[::downsample_factor]
STA3u_ds = STA3u[::downsample_factor]
STA4d_ds = STA4d[::downsample_factor]
STA5u_ds = STA5u[::downsample_factor]
STA6d_ds = STA6d[::downsample_factor]
STA7u_ds = STA7u[::downsample_factor]
STA8d_ds = STA8d[::downsample_factor]
STA9u_ds = STA9u[::downsample_factor]
STA10d_ds = STA10d[::downsample_factor]
WB06_ds = WB06[::downsample_factor]
WB08_ds = WB08[::downsample_factor]
WB10_ds = WB10[::downsample_factor]
WW25_ds = WW25[::downsample_factor]
BTc_ds = BTc[::downsample_factor]
BTl_ds = BTl[::downsample_factor]
BTr_ds = BTr[::downsample_factor]
CURd_ds = CURd[::downsample_factor]
CURu_ds = CURu[::downsample_factor]
CUTlf_ds = CUTlf[::downsample_factor]
CUTls_ds = CUTls[::downsample_factor]
CUTrf_ds = CUTrf[::downsample_factor]
CUTrs_ds = CUTrs[::downsample_factor]
JUfb_ds = JUfb[::downsample_factor]
JUh_ds = JUh[::downsample_factor]
JUfv_ds = JUfv[::downsample_factor]
JU901_ds = JU901[::downsample_factor]
JU902_ds = JU902[::downsample_factor]
JU180_ds = JU180[::downsample_factor]
JUl_ds = JUl[::downsample_factor]
LW25lc_ds = LW25lc[::downsample_factor]
LW25ll_ds = LW25ll[::downsample_factor]
LW25rc_ds = LW25rc[::downsample_factor]
LW25rr_ds = LW25rr[::downsample_factor]
LW0lc_ds = LW0lc[::downsample_factor]
LW0ll_ds = LW0ll[::downsample_factor]
LW0rc_ds = LW0rc[::downsample_factor]
LW0rr_ds = LW0rr[::downsample_factor]
LU1_ds = LU1[::downsample_factor]
LU2l_ds = LU2l[::downsample_factor]
LU2r_ds = LU2r[::downsample_factor]
ME_ds = ME[::downsample_factor]
STSsn_ds = STSsn[::downsample_factor]
STSsa_ds = STSsa[::downsample_factor]
PO_ds = PO[::downsample_factor]
PU_ds = PU[::downsample_factor]
STE2l_ds = STE2l[::downsample_factor]
STE2r_ds = STE2r[::downsample_factor]
STStn_ds = STStn[::downsample_factor]
TR_ds = TR[::downsample_factor]
TOW_ds = TOW[::downsample_factor]
TUlt_ds = TUlt[::downsample_factor]
TUrt_ds = TUrt[::downsample_factor]
TW_ds = TW[::downsample_factor]

# %%
# make new downsampled training and testing datasets
cyclic_dfs_ds = [WDbk_ds,WDhw_ds,WDhk_ds,WDtw_ds,WId5_ds,WIu5_ds,WId10_ds,WIu10_ds,WN06_ds,WN12_ds,WN18_ds,WN20_ds,WN25_ds,WNsh_ds,WNsk_ds,WO_ds,SS_ds,SQ0_ds,SQ25_ds,STA1u_ds,STA2d_ds,STA3u_ds,STA4d_ds,STA5u_ds,STA6d_ds,STA7u_ds,STA8d_ds,STA9u_ds,STA10d_ds,WB06_ds,WB08_ds,WB10_ds,WW25_ds]
non_cyclic_dfs_ds = [BTc_ds,BTl_ds,BTr_ds,CURd_ds,CURu_ds,CUTlf_ds,CUTls_ds,CUTrf_ds,CUTrs_ds,JUfb_ds,JUh_ds,JUfv_ds,JU901_ds,JU902_ds,JU180_ds,JUl_ds,LW25lc_ds,LW25ll_ds,LW25rc_ds,LW25rr_ds,LW0lc_ds,LW0ll_ds,LW0rc_ds,LW0rr_ds,LU1_ds,LU2l_ds,LU2r_ds,ME_ds,STSsn_ds,STSsa_ds,PO_ds,PU_ds,STE2l_ds,STE2r_ds,STStn_ds,TR_ds,TOW_ds,TUlt_ds,TUrt_ds,TW_ds]

# contains all of the training dfs (all of which are cyclic)
train_dfs_ds = [cyclic_dfs_ds[i] for i in train_cyclic_dfs_nums]

# contains all of the trtesting dfs (a couple of the cyclic and all of the non-cyclic)
test_dfs_cyclic_ds = [cyclic_dfs_ds[i] for i in test_cyclic_dfs_nums]
test_dfs_ds = np.concatenate((test_dfs_cyclic_ds, non_cyclic_dfs_ds))

# concatenate the cleaned dataframes back together
train_combined_df_ds = pd.concat(train_dfs_ds)
test_combined_df_ds = pd.concat(test_dfs_ds)

# apply the cyclic action detection algorithm on the combined training and testing dataframes
detect_cyclic_actions(train_combined_df_ds, test_combined_df_ds)

# %%
BTc_ds

# %%
#1/10th of the data, better accuracy and much faster
# because it is cyclic, make each point a vector of the past 2 points (0.3 seconds) to incorporate an element of time into the SVM
import pandas as pd

# Assuming the cyclic and non-cyclic DataFrames defined in 'cyclic_dfs_ds' and 'non_cyclic_dfs_ds'

def process_dataframe(df):
    # shift the current row and the previous two rows downwards
    previous_two_rows = df.shift(1).add_prefix('prev_')
    previous_one_row = df.shift(2).add_prefix('prev2_')

    # concatenate the three shifted DataFrames along the columns axis
    new_df = pd.concat([df, previous_one_row, previous_two_rows], axis=1)

    # drop rows with NaN values (the first two rows, as they don't have previous rows)
    new_df = new_df.dropna()

    # drop the 'prev_row_Class' and 'prev2_row_Class' columns
    new_df = new_df.drop(columns=['prev_Class', 'prev2_Class'])

    return new_df

# process each DataFrame in 'all_dfs' with the suffix '_ds_t'
WDbk_ds_t = process_dataframe(WDbk_ds)
WDhw_ds_t = process_dataframe(WDhw_ds)
WDhk_ds_t = process_dataframe(WDhk_ds)
WDtw_ds_t = process_dataframe(WDtw_ds)
WId5_ds_t = process_dataframe(WId5_ds)
WIu5_ds_t = process_dataframe(WIu5_ds)
WId10_ds_t = process_dataframe(WId10_ds)
WIu10_ds_t = process_dataframe(WIu10_ds)
WN06_ds_t = process_dataframe(WN06_ds)
WN12_ds_t = process_dataframe(WN12_ds)
WN18_ds_t = process_dataframe(WN18_ds)
WN20_ds_t = process_dataframe(WN20_ds)
WN25_ds_t = process_dataframe(WN25_ds)
WNsh_ds_t = process_dataframe(WNsh_ds)
WNsk_ds_t = process_dataframe(WNsk_ds)
WO_ds_t = process_dataframe(WO_ds)
SS_ds_t = process_dataframe(SS_ds)
SQ0_ds_t = process_dataframe(SQ0_ds)
SQ25_ds_t = process_dataframe(SQ25_ds)
STA1u_ds_t = process_dataframe(STA1u_ds)
STA2d_ds_t = process_dataframe(STA2d_ds)
STA3u_ds_t = process_dataframe(STA3u_ds)
STA4d_ds_t = process_dataframe(STA4d_ds)
STA5u_ds_t = process_dataframe(STA5u_ds)
STA6d_ds_t = process_dataframe(STA6d_ds)
STA7u_ds_t = process_dataframe(STA7u_ds)
STA8d_ds_t = process_dataframe(STA8d_ds)
STA9u_ds_t = process_dataframe(STA9u_ds)
STA10d_ds_t = process_dataframe(STA10d_ds)
WB06_ds_t = process_dataframe(WB06_ds)
WB08_ds_t = process_dataframe(WB08_ds)
WB10_ds_t = process_dataframe(WB10_ds)
WW25_ds_t = process_dataframe(WW25_ds)
BTc_ds_t = process_dataframe(BTc_ds)
BTl_ds_t = process_dataframe(BTl_ds)
BTr_ds_t = process_dataframe(BTr_ds)
CURd_ds_t = process_dataframe(CURd_ds)
CURu_ds_t = process_dataframe(CURu_ds)
CUTlf_ds_t = process_dataframe(CUTlf_ds)
CUTls_ds_t = process_dataframe(CUTls_ds)
CUTrf_ds_t = process_dataframe(CUTrf_ds)
CUTrs_ds_t = process_dataframe(CUTrs_ds)
JUfb_ds_t = process_dataframe(JUfb_ds)
JUh_ds_t = process_dataframe(JUh_ds)
JUfv_ds_t = process_dataframe(JUfv_ds)
JU901_ds_t = process_dataframe(JU901_ds)
JU902_ds_t = process_dataframe(JU902_ds)
JU180_ds_t = process_dataframe(JU180_ds)
JUl_ds_t = process_dataframe(JUl_ds)
LW25lc_ds_t = process_dataframe(LW25lc_ds)
LW25ll_ds_t = process_dataframe(LW25ll_ds)
LW25rc_ds_t = process_dataframe(LW25rc_ds)
LW25rr_ds_t = process_dataframe(LW25rr_ds)
LW0lc_ds_t = process_dataframe(LW0lc_ds)
LW0ll_ds_t = process_dataframe(LW0ll_ds)
LW0rc_ds_t = process_dataframe(LW0rc_ds)
LW0rr_ds_t = process_dataframe(LW0rr_ds)
LU1_ds_t = process_dataframe(LU1_ds)
LU2l_ds_t = process_dataframe(LU2l_ds)
LU2r_ds_t = process_dataframe(LU2r_ds)
ME_ds_t = process_dataframe(ME_ds)
STSsn_ds_t = process_dataframe(STSsn_ds)
STSsa_ds_t = process_dataframe(STSsa_ds)
PO_ds_t = process_dataframe(PO_ds)
PU_ds_t = process_dataframe(PU_ds)
STE2l_ds_t = process_dataframe(STE2l_ds)
STE2r_ds_t = process_dataframe(STE2r_ds)
STStn_ds_t = process_dataframe(STStn_ds)
TR_ds_t = process_dataframe(TR_ds)
TOW_ds_t = process_dataframe(TOW_ds)
TUlt_ds_t = process_dataframe(TUlt_ds)
TUrt_ds_t = process_dataframe(TUrt_ds)
TW_ds_t = process_dataframe(TW_ds)

# %%
import matplotlib.pyplot as plt
from sklearn.neighbors import NearestNeighbors

def plot_k_distance(data, k):
    # fit the k-nearest neighbor model
    nbrs = NearestNeighbors(n_neighbors=k+1, algorithm='auto').fit(data)
    distances, indices = nbrs.kneighbors(data)

    # sort the distances for plotting
    distances = np.sort(distances[:, k], axis=0)

    # plot the k-distance graph
    plt.plot(np.arange(len(data)), distances)
    plt.xlabel('Data Points (sorted)')
    plt.ylabel(f'{k}-Distance')
    plt.title(f'Elbow Method for Optimal Epsilon (k = {k})')
    plt.show()

def detect_cyclic_actions2(train_df, test_df):
    # separate features and labels for training
    X_train = train_df.drop(columns=['time', 'Class'])
    y_train = train_df['Class']

    # normalize the features
    scaler = StandardScaler()
    X_train_normalized = scaler.fit_transform(X_train)

    # Step 2: Apply DBSCAN clustering on the training data
    dbscan = DBSCAN(eps=0.9, min_samples=5)
    train_df['cluster_label'] = dbscan.fit_predict(X_train_normalized)

    # Step 3: Train the One-Class SVM
    # filter out the outliers (cluster label = -1)
    X_train_filtered = X_train_normalized[train_df['cluster_label'] != -1]
    if X_train_filtered.shape[0] == 0:
        print("No inliers found in training data. Adjust DBSCAN parameters or consider other preprocessing steps.")
        return

    # create and train the One-Class SVM classifier
    classifier = OneClassSVM(kernel='linear', nu=0.1)
    classifier.fit(X_train_filtered)

    # Step 4: Test the classifier
    # separate features and labels for testing
    X_test = test_df.drop(columns=['time', 'Class'])
    y_test = test_df['Class']

    # normalize the features for testing
    X_test_normalized = scaler.transform(X_test)

    # predict the labels using the trained One-Class SVM classifier
    predicted_labels = classifier.predict(X_test_normalized)

    # convert predicted labels (-1 for outliers, 1 for inliers) to binary labels (0 for outliers, 1 for inliers)
    binary_labels = (predicted_labels == 1).astype(int)

    # evaluate the classifier
    accuracy = accuracy_score(y_test, binary_labels)
    print(f"Accuracy: {accuracy:.2f}")
    print(classification_report(y_test, binary_labels))

# %%
def detect_cyclic_actions_rbf(train_df, test_df):
    # separate features and labels for training
    X_train = train_df.drop(columns=['time', 'Class', 'cluster_label'])
    y_train = train_df['Class']

    # normalize the features
    scaler = StandardScaler()
    X_train_normalized = scaler.fit_transform(X_train)

    # Step 2: Apply DBSCAN clustering on the training data
    dbscan = DBSCAN(eps=0.9, min_samples=5)
    train_df['cluster_label'] = dbscan.fit_predict(X_train_normalized)

    # Step 3: Train the One-Class SVM
    # filter out the outliers (cluster label = -1)
    X_train_filtered = X_train_normalized[train_df['cluster_label'] != -1]
    if X_train_filtered.shape[0] == 0:
        print("No inliers found in training data. Adjust DBSCAN parameters or consider other preprocessing steps.")
        return

    # Create and train the One-Class SVM classifier
    classifier = OneClassSVM(kernel='rbf', nu=0.1)
    classifier.fit(X_train_filtered)

    # Step 4: Test the classifier
    # Separate features and labels for testing
    X_test = test_df.drop(columns=['time', 'Class'])
    y_test = test_df['Class']

    # normalize the features for testing
    X_test_normalized = scaler.transform(X_test)

    # predict the labels using the trained One-Class SVM classifier
    predicted_labels = classifier.predict(X_test_normalized)

    # convert predicted labels (-1 for outliers, 1 for inliers) to binary labels (0 for outliers, 1 for inliers)
    binary_labels = (predicted_labels == 1).astype(int)

    # evaluate the classifier
    accuracy = accuracy_score(y_test, binary_labels)
    print(f"Accuracy: {accuracy:.2f}")
    print(classification_report(y_test, binary_labels))

# %%
def detect_cyclic_actions_polynomial(train_df, test_df):
    # separate features and labels for training
    X_train = train_df.drop(columns=['time', 'Class', 'cluster_label'])
    y_train = train_df['Class']

    # normalize the features
    scaler = StandardScaler()
    X_train_normalized = scaler.fit_transform(X_train)

    # Step 2: Apply DBSCAN clustering on the training data
    dbscan = DBSCAN(eps=0.9, min_samples=5)
    train_df['cluster_label'] = dbscan.fit_predict(X_train_normalized)

    # Step 3: Train the One-Class SVM
    # filter out the outliers (cluster label = -1)
    X_train_filtered = X_train_normalized[train_df['cluster_label'] != -1]
    if X_train_filtered.shape[0] == 0:
        print("No inliers found in training data. Adjust DBSCAN parameters or consider other preprocessing steps.")
        return

    # create and train the One-Class SVM classifier
    classifier = OneClassSVM(kernel='poly', nu=0.1)
    classifier.fit(X_train_filtered)

    # Step 4: Test the classifier
    # separate features and labels for testing
    X_test = test_df.drop(columns=['time', 'Class'])
    y_test = test_df['Class']

    # normalize the features for testing
    X_test_normalized = scaler.transform(X_test)

    # predict the labels using the trained One-Class SVM classifier
    predicted_labels = classifier.predict(X_test_normalized)

    # convert predicted labels (-1 for outliers, 1 for inliers) to binary labels (0 for outliers, 1 for inliers)
    binary_labels = (predicted_labels == 1).astype(int)

    # evaluate the classifier
    accuracy = accuracy_score(y_test, binary_labels)
    print(f"Accuracy: {accuracy:.2f}")
    print(classification_report(y_test, binary_labels))

# %%
cyclic_dfs_ds_t = [WDbk_ds_t,WDhw_ds_t,WDhk_ds_t,WDtw_ds_t,WId5_ds_t,WIu5_ds_t,WId10_ds_t,WIu10_ds_t,WN06_ds_t,WN12_ds_t,WN18_ds_t,WN20_ds_t,WN25_ds_t,WNsh_ds_t,WNsk_ds_t,WO_ds_t,SS_ds_t,SQ0_ds_t,SQ25_ds_t,STA1u_ds_t,STA2d_ds_t,STA3u_ds_t,STA4d_ds_t,STA5u_ds_t,STA6d_ds_t,STA7u_ds_t,STA8d_ds_t,STA9u_ds_t,STA10d_ds_t,WB06_ds_t,WB08_ds_t,WB10_ds_t,WW25_ds_t]
non_cyclic_dfs_ds_t = [BTc_ds_t,BTl_ds_t,BTr_ds_t,CURd_ds_t,CURu_ds_t,CUTlf_ds_t,CUTls_ds_t,CUTrf_ds_t,CUTrs_ds_t,JUfb_ds_t,JUh_ds_t,JUfv_ds_t,JU901_ds_t,JU902_ds_t,JU180_ds_t,JUl_ds_t,LW25lc_ds_t,LW25ll_ds_t,LW25rc_ds_t,LW25rr_ds_t,LW0lc_ds_t,LW0ll_ds_t,LW0rc_ds_t,LW0rr_ds_t,LU1_ds_t,LU2l_ds_t,LU2r_ds_t,ME_ds_t,STSsn_ds_t,STSsa_ds_t,PO_ds_t,PU_ds_t,STE2l_ds_t,STE2r_ds_t,STStn_ds_t,TR_ds_t,TOW_ds_t,TUlt_ds_t,TUrt_ds_t,TW_ds_t]

# make new training and testing datasets

# contains all of the training dfs (all of which are cyclic)
train_dfs_ds_t = [cyclic_dfs_ds_t[i] for i in train_cyclic_dfs_nums]

# contains all of the testing dfs (a couple of the cyclic and all of the non-cyclic)
test_dfs_cyclic_ds_t = [cyclic_dfs_ds_t[i] for i in test_cyclic_dfs_nums]
test_dfs_ds_t = np.concatenate((test_dfs_cyclic_ds_t, non_cyclic_dfs_ds_t))

# concatenate the cleaned dataframes back together
train_combined_df_ds_t = pd.concat(train_dfs_ds_t)
test_combined_df_ds_t = pd.concat(test_dfs_ds_t)

# %% [markdown]
# ### Ablation: DBSCAN & One-Class SVM, Downsampling

# %%
print(list(train_combined_df_ds_t.columns))
print(list(test_combined_df_ds_t.columns))

# drop hip flexion columns
train_combined_df_ds_t_flexionDrop = train_combined_df_ds_t.drop(columns=['hip_flexion_r', 'prev_hip_flexion_r', 'prev2_hip_flexion_r', 'hip_flexion_l', 'prev_hip_flexion_l', 'prev2_hip_flexion_l'])
test_combined_df_ds_t_flexionDrop = test_combined_df_ds_t.drop(columns=['hip_flexion_r', 'prev_hip_flexion_r', 'prev2_hip_flexion_r', 'hip_flexion_l', 'prev_hip_flexion_l', 'prev2_hip_flexion_l'])

# drop hip rotation columns
train_combined_df_ds_t_rotationDrop = train_combined_df_ds_t.drop(columns=['hip_rotation_r', 'prev_hip_rotation_r', 'prev2_hip_rotation_r', 'hip_rotation_l', 'prev_hip_rotation_l', 'prev2_hip_rotation_l'])
test_combined_df_ds_t_rotationDrop = test_combined_df_ds_t.drop(columns=['hip_rotation_r', 'prev_hip_rotation_r', 'prev2_hip_rotation_r', 'hip_rotation_l', 'prev_hip_rotation_l', 'prev2_hip_rotation_l'])

# drop knee angle columns
train_combined_df_ds_t_kneeAngleDrop = train_combined_df_ds_t.drop(columns=['knee_angle_r', 'prev_knee_angle_r', 'prev2_knee_angle_r', 'knee_angle_l', 'prev_knee_angle_l', 'prev2_knee_angle_l'])
test_combined_df_ds_t_kneeAngleDrop = test_combined_df_ds_t.drop(columns=['knee_angle_r', 'prev_knee_angle_r', 'prev2_knee_angle_r', 'knee_angle_l', 'prev_knee_angle_l', 'prev2_knee_angle_l'])

# drop knee velocity columns
train_combined_df_ds_t_kneeVelocityDrop = train_combined_df_ds_t.drop(columns=['knee_velocity_r', 'prev_knee_velocity_r', 'prev2_knee_velocity_r', 'knee_velocity_l', 'prev_knee_velocity_l', 'prev2_knee_velocity_l'])
test_combined_df_ds_t_kneeVelocityDrop = test_combined_df_ds_t.drop(columns=['knee_velocity_r', 'prev_knee_velocity_r', 'prev2_knee_velocity_r', 'knee_velocity_l', 'prev_knee_velocity_l', 'prev2_knee_velocity_l'])

# drop ankle angle columns
train_combined_df_ds_t_ankleAngleDrop = train_combined_df_ds_t.drop(columns=['ankle_angle_r', 'prev_ankle_angle_r', 'prev2_ankle_angle_r', 'ankle_angle_l', 'prev_ankle_angle_l', 'prev2_ankle_angle_l'])
test_combined_df_ds_t_ankleAngleDrop = test_combined_df_ds_t.drop(columns=['ankle_angle_r', 'prev_ankle_angle_r', 'prev2_ankle_angle_r', 'ankle_angle_l', 'prev_ankle_angle_l', 'prev2_ankle_angle_l'])

# apply the cyclic action detection algorithm on the combined downsampled training and testing dataframes
print("\n")
print("Original")
detect_cyclic_actions2(train_combined_df_ds_t, test_combined_df_ds_t)
print("Dropped Hip Flexion")
detect_cyclic_actions2(train_combined_df_ds_t_flexionDrop, test_combined_df_ds_t_flexionDrop)
print("Dropped Hip Rotation")
detect_cyclic_actions2(train_combined_df_ds_t_rotationDrop, test_combined_df_ds_t_rotationDrop)
print("Dropped Knee Angle")
detect_cyclic_actions2(train_combined_df_ds_t_kneeAngleDrop, test_combined_df_ds_t_kneeAngleDrop)
print("Dropped Knee Velocity")
detect_cyclic_actions2(train_combined_df_ds_t_kneeVelocityDrop, test_combined_df_ds_t_kneeVelocityDrop)
print("Dropped Ankle Angle")
detect_cyclic_actions2(train_combined_df_ds_t_ankleAngleDrop, test_combined_df_ds_t_ankleAngleDrop)

# %% [markdown]
# ### Ablation: DBSCAN & One Class SVM, RBF

# %%
print(list(train_combined_df_ds_t.columns))
print(list(test_combined_df_ds_t.columns))

# apply the cyclic action detection algorithm on the combined downsampled training and testing dataframes
print("\n")
print("Original")
detect_cyclic_actions_rbf(train_combined_df_ds_t, test_combined_df_ds_t)
print("Dropped Hip Flexion")
detect_cyclic_actions_rbf(train_combined_df_ds_t_flexionDrop, test_combined_df_ds_t_flexionDrop)
print("Dropped Hip Rotation")
detect_cyclic_actions_rbf(train_combined_df_ds_t_rotationDrop, test_combined_df_ds_t_rotationDrop)
print("Dropped Knee Angle")
detect_cyclic_actions_rbf(train_combined_df_ds_t_kneeAngleDrop, test_combined_df_ds_t_kneeAngleDrop)
print("Dropped Knee Velocity")
detect_cyclic_actions_rbf(train_combined_df_ds_t_kneeVelocityDrop, test_combined_df_ds_t_kneeVelocityDrop)
print("Dropped Ankle Angle")
detect_cyclic_actions_rbf(train_combined_df_ds_t_ankleAngleDrop, test_combined_df_ds_t_ankleAngleDrop)

# %% [markdown]
# ### Ablation: DBSCAN & One Class SVM, Polynomial

# %%
print(list(train_combined_df_ds_t.columns))
print(list(test_combined_df_ds_t.columns))

# apply the cyclic action detection algorithm on the combined downsampled training and testing dataframes
print("\n")
print("Original")
detect_cyclic_actions_polynomial(train_combined_df_ds_t, test_combined_df_ds_t)
print("Dropped Hip Flexion")
detect_cyclic_actions_polynomial(train_combined_df_ds_t_flexionDrop, test_combined_df_ds_t_flexionDrop)
print("Dropped Hip Rotation")
detect_cyclic_actions_polynomial(train_combined_df_ds_t_rotationDrop, test_combined_df_ds_t_rotationDrop)
print("Dropped Knee Angle")
detect_cyclic_actions_polynomial(train_combined_df_ds_t_kneeAngleDrop, test_combined_df_ds_t_kneeAngleDrop)
print("Dropped Knee Velocity")
detect_cyclic_actions_polynomial(train_combined_df_ds_t_kneeVelocityDrop, test_combined_df_ds_t_kneeVelocityDrop)
print("Dropped Ankle Angle")
detect_cyclic_actions_polynomial(train_combined_df_ds_t_ankleAngleDrop, test_combined_df_ds_t_ankleAngleDrop)

# %% [markdown]
# # Elbow Plot

# %%
def elbow_plot(train_df):
  # Separate features and labels for training
  X_train = train_df.drop(columns=['time', 'Class'])
  y_train = train_df['Class']

  # Normalize the features
  scaler = StandardScaler()
  X_train_normalized = scaler.fit_transform(X_train)

  k = 5
  plot_k_distance(X_train_normalized, k)

elbow_plot(train_combined_df_ds_t)
elbow_plot(train_combined_df_ds)
elbow_plot(train_combined_df)

# %% [markdown]
# # Model: Local Outlier Factor

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.neighbors import LocalOutlierFactor
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, accuracy_score
from sklearn.cluster import DBSCAN

def apply_lof(train_df, test_df):
    # Separate features and labels for training and testing
    X_train = train_df.drop(columns=['time', 'Class', 'cluster_label'])
    y_train = train_df['Class']
    X_test = test_df.drop(columns=['time', 'Class'])
    y_test = test_df['Class']

    # Normalize the features
    scaler = StandardScaler()
    X_train_normalized = scaler.fit_transform(X_train)
    X_test_normalized = scaler.transform(X_test)

    # Step 2: Train the LOF model using the cyclic data
    cyclic_train_mask = (y_train == 1)
    X_train_cyclic = X_train_normalized[cyclic_train_mask]

    # Create and fit the LOF model using the cyclic training data
    lof_model = LocalOutlierFactor(n_neighbors=20, contamination=0.1)
    y_pred_train_cyclic = lof_model.fit_predict(X_train_cyclic)

    # Step 3: Test the LOF model on the test data
    y_pred_test = lof_model.fit_predict(X_test_normalized)

    # Convert predicted labels (-1 for outliers, 1 for inliers) to binary labels (0 for outliers, 1 for inliers)
    binary_labels_train_cyclic = (y_pred_train_cyclic == 1).astype(int)
    binary_labels_test = (y_pred_test == 1).astype(int)

    # Evaluate the model
    print("Train set (cyclic data only):")
    print(classification_report(y_train[cyclic_train_mask], binary_labels_train_cyclic))
    print("Test set:")
    print(classification_report(y_test, binary_labels_test))

apply_lof(train_combined_df_ds_t, test_combined_df_ds_t)
# Out:
# Train set (cyclic data only):
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         0
#          1.0       1.00      0.90      0.95      4167
#
#     accuracy                           0.90      4167
#    macro avg       0.50      0.45      0.47      4167
# weighted avg       1.00      0.90      0.95      4167
#
# Test set:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.11      0.19     15124
#          1.0       0.06      1.00      0.11       871
#
#     accuracy                           0.15     15995
#    macro avg       0.53      0.55      0.15     15995
# weighted avg       0.95      0.15      0.19     15995

# %% [markdown]
# ### Ablation: LOF 1

# %%
def apply_lof2(train_df, test_df):
    # Separate features and labels for training and testing
    X_train = train_df.drop(columns=['time', 'Class', 'cluster_label'])
    y_train = train_df['Class']
    X_test = test_df.drop(columns=['time', 'Class'])
    y_test = test_df['Class']

    # Normalize the features
    scaler = StandardScaler()
    X_train_normalized = scaler.fit_transform(X_train)
    X_test_normalized = scaler.transform(X_test)

    # Step 2: Train the LOF model using the cyclic data
    cyclic_train_mask = (y_train == 1)
    X_train_cyclic = X_train_normalized[cyclic_train_mask]

    # Create and fit the LOF model using the cyclic training data
    lof_model = LocalOutlierFactor(n_neighbors=40, contamination=0.5)
    y_pred_train_cyclic = lof_model.fit_predict(X_train_cyclic)

    # Step 3: Test the LOF model on the test data
    y_pred_test = lof_model.fit_predict(X_test_normalized)

    # Convert predicted labels (-1 for outliers, 1 for inliers) to binary labels (0 for outliers, 1 for inliers)
    binary_labels_train_cyclic = (y_pred_train_cyclic == 1).astype(int)
    binary_labels_test = (y_pred_test == 1).astype(int)

    # Evaluate the model
    print("Train set (cyclic data only):")
    print(classification_report(y_train[cyclic_train_mask], binary_labels_train_cyclic))
    print("Test set:")
    print(classification_report(y_test, binary_labels_test))

apply_lof(train_combined_df_ds_t, test_combined_df_ds_t)
# Out:
# Train set (cyclic data only):
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         0
#          1.0       1.00      0.90      0.95      4167
#
#     accuracy                           0.90      4167
#    macro avg       0.50      0.45      0.47      4167
# weighted avg       1.00      0.90      0.95      4167
#
# Test set:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.11      0.19     15124
#          1.0       0.06      1.00      0.11       871
#
#     accuracy                           0.15     15995
#    macro avg       0.53      0.55      0.15     15995
# weighted avg       0.95      0.15      0.19     15995

# %% [markdown]
# ### Ablation: LOF 2

# %% [markdown]
# # Model: Convolutional Neural Network

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.metrics import classification_report, accuracy_score
from sklearn.preprocessing import StandardScaler

def apply_cnn(train_df, test_df):
    # Separate features and labels for training and testing
    X_train = train_df.drop(columns=['time', 'Class','cluster_label']).values
    y_train = train_df['Class'].values
    X_test = test_df.drop(columns=['time', 'Class']).values
    y_test = test_df['Class'].values
    print(X_train.shape)
    print(X_test.shape)

    # Normalize the features
    scaler = StandardScaler()
    X_train_normalized = scaler.fit_transform(X_train)
    X_test_normalized = scaler.transform(X_test)

    # Reshape the input data to be suitable for 1D Convolutional Neural Network
    X_train_cnn = X_train_normalized.reshape(X_train_normalized.shape[0], X_train_normalized.shape[1], 1)
    X_test_cnn = X_test_normalized.reshape(X_test_normalized.shape[0], X_test_normalized.shape[1], 1)

    # Create and compile the 1D CNN model
    model = tf.keras.Sequential([
        tf.keras.layers.Conv1D(filters=32, kernel_size=3, activation='relu', input_shape=(X_train_normalized.shape[1], 1)),
        tf.keras.layers.MaxPooling1D(pool_size=2),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(64, activation='relu'),
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])

    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

    # Train the model
    model.fit(X_train_cnn, y_train, epochs=10, batch_size=32, verbose=1)

    # Predict the labels on the test data
    y_pred_proba = model.predict(X_test_cnn)
    y_pred = np.round(y_pred_proba).astype(int).flatten()

    # Evaluate the classifier
    accuracy = accuracy_score(y_test, y_pred)
    print(f"Accuracy: {accuracy:.2f}")
    print(classification_report(y_test, y_pred))

# Assuming you have the train_combined_df_ds_t (cyclic data for training) and test_combined_df_ds_t (mixture of cyclic and non-cyclic data for testing) DataFrames
apply_cnn(train_combined_df_ds_t, test_combined_df_ds_t)
# Out:
# (4167, 218)
# (15995, 218)
# Epoch 1/10
# 131/131 [==============================] - 2s 10ms/step - loss: 0.0067 - accuracy: 0.9974
# Epoch 2/10
# 131/131 [==============================] - 1s 9ms/step - loss: 1.4291e-05 - accuracy: 1.0000
# Epoch 3/10
# 131/131 [==============================] - 2s 12ms/step - loss: 1.0626e-05 - accuracy: 1.0000
# Epoch 4/10
# 131/131 [==============================] - 2s 14ms/step - loss: 7.8334e-06 - accuracy: 1.0000
# Epoch 5/10
# 131/131 [==============================] - 2s 12ms/step - loss: 5.9320e-06 - accuracy: 1.0000
# Epoch 6/10
# 131/131 [==============================] - 1s 10ms/step - loss: 4.6025e-06 - accuracy: 1.0000
# Epoch 7/10
# 131/131 [==============================] - 1s 10ms/step - loss: 3.6257e-06 - accuracy: 1.0000
# Epoch 8/10
# 131/131 [==============================] - 1s 10ms/step - loss: 2.9058e-06 - accuracy: 1.0000
# Epoch 9/10
# ...

# %%
def apply_cnn2(train_df, test_df):
    # Separate features and labels for training and testing
    X_train = train_df.drop(columns=['time', 'Class','cluster_label']).values
    y_train = train_df['Class'].values
    X_test = test_df.drop(columns=['time', 'Class']).values
    y_test = test_df['Class'].values
    print(X_train.shape)
    print(X_test.shape)

    # Normalize the features
    scaler = StandardScaler()
    X_train_normalized = scaler.fit_transform(X_train)
    X_test_normalized = scaler.transform(X_test)

    # Reshape the input data to be suitable for 1D Convolutional Neural Network
    X_train_cnn = X_train_normalized.reshape(X_train_normalized.shape[0], X_train_normalized.shape[1], 1)
    X_test_cnn = X_test_normalized.reshape(X_test_normalized.shape[0], X_test_normalized.shape[1], 1)

    # Create and compile the 1D CNN model
    model = tf.keras.Sequential([
        tf.keras.layers.Conv1D(filters=64, kernel_size=4, activation='relu', input_shape=(X_train_normalized.shape[1], 1)),
        tf.keras.layers.MaxPooling1D(pool_size=2),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])

    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

    # Train the model
    model.fit(X_train_cnn, y_train, epochs=10, batch_size=32, verbose=1)

    # Predict the labels on the test data
    y_pred_proba = model.predict(X_test_cnn)
    y_pred = np.round(y_pred_proba).astype(int).flatten()

    # Evaluate the classifier
    accuracy = accuracy_score(y_test, y_pred)
    print(f"Accuracy: {accuracy:.2f}")
    print(classification_report(y_test, y_pred))

# Assuming you have the train_combined_df_ds_t (cyclic data for training) and test_combined_df_ds_t (mixture of cyclic and non-cyclic data for testing) DataFrames
apply_cnn2(train_combined_df_ds_t, test_combined_df_ds_t)

# %%
def apply_cnn3(train_df, test_df):
    # Separate features and labels for training and testing
    X_train = train_df.drop(columns=['time', 'Class','cluster_label']).values
    y_train = train_df['Class'].values
    X_test = test_df.drop(columns=['time', 'Class']).values
    y_test = test_df['Class'].values
    print(X_train.shape)
    print(X_test.shape)

    # Normalize the features
    scaler = StandardScaler()
    X_train_normalized = scaler.fit_transform(X_train)
    X_test_normalized = scaler.transform(X_test)

    # Reshape the input data to be suitable for 1D Convolutional Neural Network
    X_train_cnn = X_train_normalized.reshape(X_train_normalized.shape[0], X_train_normalized.shape[1], 1)
    X_test_cnn = X_test_normalized.reshape(X_test_normalized.shape[0], X_test_normalized.shape[1], 1)

    # Create and compile the 1D CNN model
    model = tf.keras.Sequential([
        tf.keras.layers.Conv1D(filters=32, kernel_size=3, activation='relu', input_shape=(X_train_normalized.shape[1], 1)),
        tf.keras.layers.MaxPooling1D(pool_size=2),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])

    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

    # Train the model
    model.fit(X_train_cnn, y_train, epochs=20, batch_size=64, verbose=1)

    # Predict the labels on the test data
    y_pred_proba = model.predict(X_test_cnn)
    y_pred = np.round(y_pred_proba).astype(int).flatten()

    # Evaluate the classifier
    accuracy = accuracy_score(y_test, y_pred)
    print(f"Accuracy: {accuracy:.2f}")
    print(classification_report(y_test, y_pred))

# Assuming you have the train_combined_df_ds_t (cyclic data for training) and test_combined_df_ds_t (mixture of cyclic and non-cyclic data for testing) DataFrames
apply_cnn3(train_combined_df_ds_t, test_combined_df_ds_t)
# Out:
# (4167, 218)
# (15995, 218)
# Epoch 1/20
# 66/66 [==============================] - 2s 17ms/step - loss: 0.0144 - accuracy: 0.9875
# Epoch 2/20
# 66/66 [==============================] - 1s 16ms/step - loss: 4.1787e-06 - accuracy: 1.0000
# Epoch 3/20
# 66/66 [==============================] - 1s 16ms/step - loss: 3.9555e-06 - accuracy: 1.0000
# Epoch 4/20
# 66/66 [==============================] - 1s 16ms/step - loss: 3.7186e-06 - accuracy: 1.0000
# Epoch 5/20
# 66/66 [==============================] - 1s 17ms/step - loss: 3.4722e-06 - accuracy: 1.0000
# Epoch 6/20
# 66/66 [==============================] - 1s 16ms/step - loss: 3.2192e-06 - accuracy: 1.0000
# Epoch 7/20
# 66/66 [==============================] - 1s 16ms/step - loss: 2.9774e-06 - accuracy: 1.0000
# Epoch 8/20
# 66/66 [==============================] - 1s 16ms/step - loss: 2.7502e-06 - accuracy: 1.0000
# Epoch 9/20
# 66/66 [==============================] - 2s 25ms/step - loss: 2.5334e-06 - accuracy: 1.0000
# ...

# %%
def apply_cnn4(train_df, test_df):
    # Separate features and labels for training and testing
    X_train = train_df.drop(columns=['time', 'Class','cluster_label']).values
    y_train = train_df['Class'].values
    X_test = test_df.drop(columns=['time', 'Class']).values
    y_test = test_df['Class'].values
    print(X_train.shape)
    print(X_test.shape)

    # Normalize the features
    scaler = StandardScaler()
    X_train_normalized = scaler.fit_transform(X_train)
    X_test_normalized = scaler.transform(X_test)

    # Reshape the input data to be suitable for 1D Convolutional Neural Network
    X_train_cnn = X_train_normalized.reshape(X_train_normalized.shape[0], X_train_normalized.shape[1], 1)
    X_test_cnn = X_test_normalized.reshape(X_test_normalized.shape[0], X_test_normalized.shape[1], 1)

    # Create and compile the 1D CNN model
    model = tf.keras.Sequential([
        tf.keras.layers.Conv1D(filters=32, kernel_size=3, activation='relu', input_shape=(X_train_normalized.shape[1], 1)),
        tf.keras.layers.MaxPooling1D(pool_size=2),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(64, activation='relu'),
        tf.keras.layers.Dropout(0.5),  # Add dropout layer with 50% dropout rate
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])

    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

    # Train the model
    model.fit(X_train_cnn, y_train, epochs=20, batch_size=32, verbose=1)

    # Predict the labels on the test data
    y_pred_proba = model.predict(X_test_cnn)
    y_pred = np.round(y_pred_proba).astype(int).flatten()

    # Evaluate the classifier
    accuracy = accuracy_score(y_test, y_pred)
    print(f"Accuracy: {accuracy:.2f}")
    print(classification_report(y_test, y_pred))

# Assuming you have the train_combined_df_ds_t (cyclic data for training) and test_combined_df_ds_t (mixture of cyclic and non-cyclic data for testing) DataFrames
apply_cnn4(train_combined_df_ds_t, test_combined_df_ds_t)
